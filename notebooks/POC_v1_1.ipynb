# %% [markdown]
# # POC in a word perspective

# %% [markdown]
# ## Main Algorithm:
#
# 1. Lemmatization
#
# 2. Protect stop words
#
#
# 3. // words (key phrases)
# Do:
# 	Look for similar words (DBSCAN)
# Replace with centroid / one of the members
# Until Embedding distance is too high or utilization is too low.
#
#
# 4. // sentences
# While K-anonymity is not reached:
# Find most similar sentences (Jaccard distance)
# Force them to be similar
#
# 5. Do some utilization test / give some stats…

# %%
# For VSCODE
# %reload_ext autoreload
# %autoreload 2

# %%
mkdir utils

# %% [markdown]
# ## 0) Upload data

# %% [markdown]
# Import libraries

# %%
import pandas as pd

# %% [markdown]
# Import project files

# %%
#import sys
#sys.path.append("utils")
# from utils import models

# %%
pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting hdbscan
#   Downloading hdbscan-0.8.29.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 61.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting umap-learn
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 3)) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 4)) (1.5.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 5)) (1.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 6)) (3.7.1)
# Collecting kneed
#   Downloading kneed-0.8.3-py3-none-any.whl (10 kB)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 8)) (4.3.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 9)) (2.0.0+cu118)
# Collecting transformers
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 94.8 MB/s eta 0:00:00
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 11)) (3.5.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 12)) (3.8.1)
# Collecting annoy
#   Downloading annoy-1.17.2.tar.gz (647 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.4/647.4 kB 37.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan->-r requirements.txt (line 1)) (1.10.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.10/dist-packages (from hdbscan->-r requirements.txt (line 1)) (0.29.34)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.10/dist-packages (from umap-learn->-r requirements.txt (line 2)) (0.56.4)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 63.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn->-r requirements.txt (line 2)) (4.65.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r requirements.txt (line 4)) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r requirements.txt (line 5)) (3.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r requirements.txt (line 6)) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r requirements.txt (line 6)) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r requirements.txt (line 6)) (8.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r requirements.txt (line 6)) (23.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r requirements.txt (line 6)) (4.39.3)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim->-r requirements.txt (line 8)) (6.3.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 9)) (2.0.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 9)) (1.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 9)) (3.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 9)) (3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 9)) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 9)) (4.5.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->-r requirements.txt (line 9)) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->-r requirements.txt (line 9)) (16.0.2)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 24.5 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 10)) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 10)) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 10)) (6.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 24.9 MB/s eta 0:00:00
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 11)) (2.4.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 11)) (1.0.9)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 11)) (3.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 11)) (2.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 11)) (2.0.7)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 11)) (3.3.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 11)) (67.7.2)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 11)) (0.10.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 11)) (1.10.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 11)) (3.0.12)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 11)) (8.1.9)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 11)) (1.0.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->-r requirements.txt (line 12)) (8.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers->-r requirements.txt (line 10)) (2023.4.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn->-r requirements.txt (line 2)) (0.39.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->-r requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->-r requirements.txt (line 10)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->-r requirements.txt (line 10)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->-r requirements.txt (line 10)) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->-r requirements.txt (line 10)) (1.26.15)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy->-r requirements.txt (line 11)) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy->-r requirements.txt (line 11)) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->-r requirements.txt (line 9)) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->-r requirements.txt (line 9)) (1.3.0)
# Building wheels for collected packages: hdbscan, umap-learn, annoy, pynndescent
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.29-cp310-cp310-linux_x86_64.whl size=3541523 sha256=b4b4d86857824030fbff32200da5ee29ecd70a179985023d943a0fe5befce11b
#   Stored in directory: /root/.cache/pip/wheels/dc/52/e3/6c6b60b126b4d5c4370cb5ac071b82950f91649d62d72f7f56
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82830 sha256=bef26d06bf5be6299cdbf58a4370f0ede1b4fe10446d9719d7e020085af2f6c0
#   Stored in directory: /root/.cache/pip/wheels/a0/e8/c6/a37ea663620bd5200ea1ba0907ab3c217042c1d035ef606acc
#   Building wheel for annoy (setup.py) ... done
#   Created wheel for annoy: filename=annoy-1.17.2-cp310-cp310-linux_x86_64.whl size=582735 sha256=91ed1ca4609e2a00e6e264ab3bdb9c35d89f50d40cf74dc51386d7f4c4d6ccac
#   Stored in directory: /root/.cache/pip/wheels/7a/d9/59/473fa56df8e39430eeda369500b4e7127f5b243ba24c3c4297
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55640 sha256=75d2647df6925ba6b40d5a1de78ae275247cb4c3e585924e9c241b05319d435d
#   Stored in directory: /root/.cache/pip/wheels/4a/38/5d/f60a40a66a9512b7e5e83517ebc2d1b42d857be97d135f1096
# Successfully built hdbscan umap-learn annoy pynndescent
# Installing collected packages: tokenizers, annoy, kneed, huggingface-hub, transformers, pynndescent, hdbscan, umap-learn
# Successfully installed annoy-1.17.2 hdbscan-0.8.29 huggingface-hub-0.14.1 kneed-0.8.3 pynndescent-0.5.10 tokenizers-0.13.3 transformers-4.28.1 umap-learn-0.5.3

# %%
from utils import nlp_utils, cluster_utils, utilization_utils, anonym_utils
# Out:
# [==================================================] 100.0% 104.8/104.8MB downloaded

# %% [markdown]
# Uploading data

# %%
train_file = 'data/df_filtered_1000.csv'

# %% [markdown]
# Getting dataframe

# %%
# %%time
# Getting the df
#df = reading_bz_file(train_file)
df = pd.read_csv(train_file)
# Out:
# CPU times: user 4.85 ms, sys: 2.05 ms, total: 6.91 ms
# Wall time: 9.72 ms

# %% [markdown]
# ## 1+2) Lemmatizing and protecting stopwords

# %% [markdown]
# Defining the word dictionary

# %%
# %%time
word_dict = nlp_utils.create_word_dict(df['txt'])
word_list = cluster_utils.get_word_list_for_clustering(word_dict)
# Out:
# CPU times: user 17.5 s, sys: 272 ms, total: 17.8 s
# Wall time: 20.8 s

# %% [markdown]
# ## 3) Word replacement

# %% [markdown]
# ### 3.1) Clustering using DBSCAN

# %% [markdown]
# #### 3.1.1) Using DBSCAN with the default euclidean distance

# %% [markdown]
# Embedding the word list

# %%
embedded_dict = cluster_utils.embed_corpus(word_list)

# %% [markdown]
# Clustering

# %%
# %%time

cluster_dict, dist_dict, labels = cluster_utils.run_clustering(embedded_dict)
# Out:
# eps 1.7651676497117053
# CPU times: user 234 ms, sys: 1.06 ms, total: 235 ms
# Wall time: 173 ms

# %%
#for key, val in dist_dict_2.items():
#    print('dist 1:', dist_dict[key], '\tdist 2:', dist_dict_2[key])

# %%
cluster_utils.plot_cluster_size_distribution_2(cluster_dict)
# Out:
# {0: ['crap', 'awful', 'ridiculous'], 1: ['soft', 'thin'], 2: ['take', 'least', 'prince', 'see', 'mess', 'probably', 'hope', 'let', 'everything', 'maybe', 'like', 'possibly', 'need', 'unfortunately', 'find', 'life', 'might', 'basically', 'otherwise', 'enough', 'five', 'pretty', 'step', 'seriously', 'something', 'give', 'damn', 'bad', 'talk', 'however', 'two', 'anyone', 'totally', 'though', 'know', 'anyway', 'many', 'exactly', 'obviously', 'old', 'sure', 'look', 'make', 'queen', 'definitely', 'think', 'well', 'swear', 'forget', 'turn', 'wow', 'mean', 'although', 'princess', 'three', 'mind', 'really', 'absolutely', 'could', 'yet', 'either', 'matter', 'catch', 'nothing', 'whether', 'yes', 'lot', 'actually', 'bring', 'perhaps', 'yeah', 'would', 'remind', 'fly', 'leave', 'anything', 'wrong', 'remember', 'tell', 'hit', 'else', 'jump', 'high', 'hold', 'crazy', 'always', 'side', 'run', 'necessary', 'hear', 'surprised', 'understand', 'wonder', 'dude', 'four', 'get', 'still', 'shame', 'except', 'certainly', 'especially', 'normally', 'guy', 'kid', 'right', 'apparently', 'much', 'hell', 'expect', 'lady', 'unless', 'way', 'rather', 'guess', 'reason'], 3: ['clark', 'peggy', 'sherry', 'mason', 'elizabeth', 'gilbert', 'browne', 'robert', 'quigley', 'turner', 'kelly', 'mrs', 'shirley', 'lightfoot', 'dane', 'keith', 'paul', 'cornwell', 'miller', 'johnson', 'rebecca', 'henry', 'joe', 'ray', 'michael', 'john', 'mark', 'boyer', 'joseph', 'tony', 'james', 'chandler', 'paxton', 'thomas', 'phillip', 'smith', 'duncan', 'sylvia', 'meyer', 'christine', 'kerouac', 'scarlett', 'carter'], 4: ['cave', 'temple'], 5: ['tube', 'combo'], 6: ['house', 'home'], 7: ['frankenstein', 'tarantino'], 8: ['incredibly', 'amazingly', 'extremely'], 9: ['insipid', 'vacuous', 'myopic', 'flimsy', 'unimaginative'], 10: ['mix', 'rock', 'pop'], 11: ['enoy', 'itit'], 12: ['discription', 'reveiw'], 13: ['lovely', 'fabulous'], 14: ['dumb', 'stupid'], 15: ['digest', 'handbook'], 16: ['potential', 'interest'], 17: ['mom', 'sister', 'dad', 'friend', 'brother'], 18: ['release', 'press'], 19: ['free', 'check'], 20: ['last', 'another', 'whole', 'next', 'every', 'first', 'second', 'year', 'soon', 'third'], 21: ['board', 'office'], 22: ['struggle', 'waste'], 23: ['hahaha', 'hahahaha'], 24: ['writer', 'author'], 25: ['learn', 'teach'], 26: ['realistic', 'unrealistic'], 27: ['flat', 'pocket', 'paint', 'shoe', 'tank', 'flip', 'boot'], 28: ['daughter', 'child', 'husband', 'wife', 'father', 'mother'], 29: ['application', 'client', 'development', 'management', 'customer'], 30: ['quality', 'product'], 31: ['green', 'blue', 'purple'], 32: ['heavy', 'speed', 'edge'], 33: ['spell', 'explain'], 34: ['walk', 'around'], 35: ['canterbury', 'limerick', 'winthrop'], 36: ['departure', 'arrival'], 37: ['white', 'black'], 38: ['break', 'time'], 39: ['august', 'december', 'oct', 'dec', 'nov'], 40: ['yesterday', 'finally', 'since', 'almost', 'already'], 41: ['snow', 'rain'], 42: ['vhs', 'bluray'], 43: ['hole', 'eye', 'bottom'], 44: ['horrible', 'terrible'], 45: ['cheap', 'expensive'], 46: ['usher', 'nelly'], 47: ['example', 'common', 'age'], 48: ['part', 'story'], 49: ['deep', 'sight'], 50: ['far', 'close', 'away'], 51: ['enjoy', 'fun'], 52: ['jacket', 'sweater'], 53: ['terrific', 'impressive', 'incredible', 'outstanding', 'brilliant', 'fantastic', 'overall', 'superb'], 54: ['wash', 'clean'], 55: ['australian', 'american', 'british'], 56: ['ear', 'tongue', 'thumb'], 57: ['carry', 'spare', 'fill', 'collect'], 58: ['deal', 'sign'], 59: ['twist', 'flick'], 60: ['l', 'b', 'r'], 61: ['aspect', 'perspective'], 62: ['stay', 'keep'], 63: ['cat', 'dog'], 64: ['nasty', 'garbage', 'trash', 'dirty'], 65: ['comic', 'comedy'], 66: ['action', 'battle'], 67: ['dish', 'soap'], 68: ['dvd', 'cd'], 69: ['reference', 'script'], 70: ['birthday', 'happy'], 71: ['head', 'cut'], 72: ['box', 'pack'], 73: ['helpful', 'useful'], 74: ['drawer', 'shelf'], 75: ['laugh', 'cry'], 76: ['shop', 'store'], 77: ['often', 'usually'], 78: ['frustrati ...

# %% [markdown]
# Plotting tSNE

# %%
# %%time
cluster_utils.plot_tsne_2(embedded_dict, labels)
# Out:
# CPU times: user 36.1 s, sys: 267 ms, total: 36.4 s
# Wall time: 21.5 s

# %%
cluster_utils.plot_tsne_2(embedded_dict, labels)

# %%
cluster_utils.plot_pca(embedded_dict,labels)

# %% [markdown]
# #### 3.1.2) Using DBSCAN with cosine distance

# %% [markdown]
# Testing DBSCAN with cosine metric

# %%
cluster_dict_cos, dist_dict_cos, labels_cos = cluster_utils.run_clustering(embedded_dict, cosine=True)
# Out:
# eps 0.053744078

# %%
cluster_utils.plot_cluster_size_distribution_2(cluster_dict_cos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-40e9e3ce659b> in <cell line: 1>()
# ----> 1 cluster_utils.plot_cluster_size_distribution_2(cluster_dict_cos)
#
# NameError: name 'cluster_dict_cos' is not defined

# %%
# %%time
cluster_utils.plot_tsne(embedded_dict, labels_cos)
# Out:
# CPU times: total: 57.2 s
# Wall time: 24.8 s

# %% [markdown]
# #### 3.1.3) Using HDBSCAN with UMAP

# %%
cluster_dict_h, dist_dict_h, labels_h = cluster_utils.run_clustering_hdbscan(embedded_dict)

# %%
cluster_utils.plot_cluster_size_distribution(cluster_dict_h)

# %%
cluster_utils.plot_tsne(embedded_dict, labels_h)

# %% [markdown]
# #### 3.1.4) Comapirson

# %%
print('Euclidian distance:\t', len(cluster_dict), 'clusters')
print('Cosine distance:\t', len(cluster_dict_cos), 'clusters')
print('HDBSCAN clustering:\t', len(cluster_dict_h), 'clusters')
# Out:
# Euclidian distance:	 110 clusters
# Cosine distance:	 49 clusters
# HDBSCAN clustering:	 52 clusters

# %% [markdown]
# Plotting Jaccard index histogram

# %%
test_dict = nlp_utils.create_word_dict(['hi, how are you?', 'I love chocolate', 'I love banana', 'he loves cola'])
test_list = cluster_utils.get_word_list_for_clustering(test_dict)
test_list
# Out:
# ['hi', 'love', 'banana', 'chocolate', 'cola']

# %% [markdown]
# Getting distance threshold

# %%
threshold = cluster_utils.define_max_threshold()
threshold
# Out:
# sim_list_best 0.82521856
# sim_list_worst 0.56748897
# 0.3036462366580963

# %% [markdown]
# ### 3.2) Replacing words in documents

# %% [markdown]
# #### 3.2.1) Based on Eucledian distance

# %%
######################### TEMP #######################
#df = df[:30]

# %%
# %%time
df_2, word_dict_2 = nlp_utils.replace_words_in_df(df, cluster_dict, dist_dict, threshold, word_dict)
# Out:
# Starting average Jaccard index: 0.18490998931057948
# Distance threshold: 0.3036462366580963
# distance: 0.1423817 	replacing ['combo', 'tube'] in pack
# distance: 0.32809252 the next cluster is too wide and wont be replaced: ['hell', 'four', 'think', 'normally', 'although', 'surprised', 'bad', 'mind', 'life', 'whether', 'leave', 'unfortunately', 'give', 'know', 'else', 'basically', 'definitely', 'yeah', 'take', 'apparently', 'dude', 'especially', 'many', 'well', 'necessary', 'maybe', 'unless', 'turn', 'look', 'sure', 'rather', 'hold', 'would', 'swear', 'run', 'matter', 'however', 'obviously', 'forget', 'kid', 'right', 'old', 'prince', 'might', 'probably', 'either', 'least', 'lady', 'need', 'mean', 'side', 'enough', 'make', 'high', 'find', 'hit', 'tell', 'shame', 'wow', 'step', 'damn', 'seriously', 'five', 'queen', 'jump', 'guy', 'hope', 'anyone', 'guess', 'perhaps', 'certainly', 'something', 'everything', 'mess', 'understand', 'crazy', 'way', 'nothing', 'much', 'anyway', 'except', 'could', 'see', 'remind', 'wrong', 'like', 'pretty', 'remember', 'possibly', 'though', 'actually', 'exactly', 'yet', 'bring', 'totally', 'yes', 'anything', 'catch', 'let', 'lot', 'hear', 'reason', 'wonder', 'fly', 'princess', 'really', 'three', 'always', 'otherwise', 'get', 'expect', 'two', 'still', 'talk', 'absolutely']
# distance: 0.12038027 	replacing ['fairly', 'somewhat'] in particularly
# distance: 0.13312031 	replacing ['learn', 'teach'] in speak
# distance: 0.13353619 	replacing ['digest', 'handbook'] in documentation
# distance: 0.1538586 	replacing ['thumb', 'tongue', 'ear'] in finger
# distance: 0.11704517 	replacing ['dumb', 'stupid'] in silly
# distance: 0.12681131 	replacing ['granddaughter', 'grandson'] in grandfather
# distance: 0.118350156 	replacing ['often', 'usually'] in rarely
# distance: 0.22881298 	replacing ['management', 'client', 'application', 'customer', 'development'] in services
# distance: 0.17075364 	replacing ['ridiculous', 'awful', 'crap'] in worse
# distance: 0.23270056 	replacing ['fantastic', 'incredible', 'overall', 'superb', 'outstanding', 'terrific', 'brilliant', 'impressive'] in exciting
# distance: 0.12934023 	replacing ['fantasy', 'ultimate'] in epic
# distance: 0.13565272 	replacing ['deep', 'sight'] in mind
# distance: 0.2931047 	replacing ['robert', 'peggy', 'lightfoot', 'joseph', 'miller', 'dane', 'gilbert', 'johnson', 'joe', 'scarlett', 'shirley', 'quigley', 'sylvia', 'phillip', 'christine', 'tony', 'boyer', 'paul', 'mrs', 'clark', 'rebecca', 'keith', 'michael', 'turner', 'duncan', 'henry', 'mason', 'carter', 'browne', 'kelly', 'meyer', 'john', 'paxton', 'sherry', 'smith', 'kerouac', 'elizabeth', 'chandler', 'mark', 'james', 'thomas', 'ray', 'cornwell'] in collins
# distance: 0.13915323 	replacing ['recent', 'previous'] in regarding
# distance: 0.12183385 	replacing ['definetely', 'definitly', 'definatly'] in definitley
# distance: 0.12112377 	replacing ['instead', 'without'] in while
# distance: 0.17481305 	replacing ['far', 'close', 'away'] in until
# distance: 0.16735181 	replacing ['elder', 'moby', 'nightwish'] in sandman
# distance: 0.13981587 	replacing ['perspective', 'aspect'] in influence
# distance: 0.22175594 	replacing ['boot', 'pocket', 'tank', 'paint', 'flat', 'shoe', 'flip'] in bag
# distance: 0.11806467 	replacing ['cat', 'dog'] in monkey
# distance: 0.13082106 	replacing ['flick', 'twist'] in tattoo
# distance: 0.16697446 	replacing ['purple', 'blue', 'green'] in yellow
# distance: 0.15239078 	replacing ['tarantino', 'frankenstein'] in hitchcock
# distance: 0.12027457 	replacing ['check', 'free'] in new
# distance: 0.15930894 	replacing ['speed', 'heavy', 'edge'] in clear
# distance: 0.13170244 	replacing ['shop', 'store'] in free
# distance: 0.13165165 	replacing ['day', 'night'] in sunday
# distance: 0.19077276 	replacing ['unimaginative', 'insipid', 'vacuous', 'flimsy', 'myopic'] in vapid
# distance: 0.14761634 	replacing ['sign', 'deal'] in trade
# distance: 0.08542067 	replacing ['horrible', 'terrible'] in cruel
# distance: 0.12821232 	replacing ['board', 'office'] in company
# distance: 0.20748773 	replacing ['dirty', 'nasty', 'trash', 'garbage'] in ass
# distance: 0.16536334 	replacing ['brother', 'sister', 'mom', 'friend', 'dad'] in daddy
# distance: 0.124564126 	replacing ['script', 'reference'] in feature
# distance: 0.15202682 	replacing ['canterbury', 'limerick', 'winthrop'] in carleton
# distance: 0.14317207 	replacing ['usher', 'nelly'] in wiz
# distance: 0.1431529 	replacing ['dish', 'soap'] in bubble
# distance: 0.16119036 	replacing ['hole', 'eye', 'bottom'] in hands
# distance: 0.08077318 	replacing ['reccommend', 'reccomend'] in somehing
# distance: 0.15720426 	replacing ['enoy', 'itit'] in vanie
# distance: 0.14323913 	replacing ['soft', 'thin'] in skin
# distance: 0.18516879 	replacing ['mother', 'daughter', 'father', 'wife', 'husband', 'child'] in woman
# distance: 0.13476329 	replacing ['reveiw', 'discription'] in rubric
# distance: 0.132492 	replacing ['head', 'cut'] in hands
# distance: 0.14859957 	replacing ['l', 'b', 'r'] in f
# distance: 0.16594043 	replacing ['amazingly', 'incredibly', 'extremely'] in insanely
# distance: 0.16573465 	replacing ['british', 'american', 'australian'] in canadian
# distance: 0.16312023 	replacing ['stick', 'loose', 'pull'] in throw
# distance: 0.14014678 	replacing ['part', 'story'] in secret
# distance: 0.13158196 	replacing ['stevie', 'wayne'] in ross
# distance: 0.15729909 	replacing ['rock', 'mix', 'pop'] in dance
# distance: 0.114184946 	replacing ['amazing', 'awesome'] in best
# distance: 0.13564105 	replacing ['expensive', 'cheap'] in cheaper
# distance: 0.11439237 	replacing ['sweater', 'jacket'] in hoodie
# distance: 0.13228288 	replacing ['useful', 'helpful'] in examples
# distance: 0.1967425 	replacing ['dec', 'oct', 'december', 'august', 'nov'] in june
# distance: 0.13329369 	replacing ['happy', 'birthday'] in thank
# distance: 0.13835907 	replacing ['temple', 'cave'] in desert
# distance: 0.12881479 	replacing ['spiderman', 'batman'] in superman
# distance: 0.1415585 	replacing ['rain', 'snow'] in sun
# distance: 0.12257018 	replacing ['drawer', 'shelf'] in storage
# distance: 0.11574734 	replacing ['verbose', 'recommendable'] in nihilistic
# distance: 0.14381021 	replacing ['lovely', 'fabulous'] in wonderful
# distance: 0.072909445 	replacing ['hahahaha', 'hahaha'] in hahahahaha
# distance: 0.12538838 	replacing ['arrival', 'departure'] in returns
# distance: 0.13113463 	replacing ['metal', 'iron'] in monster
# distance: 0.12302864 	replacing ['brooklyn', 'houston'] in chicago
# distance: 0.1934903 	replacing ['collect', 'fill', 'carry', 'spare'] in grab
# distance: 0.12196259 	replacing ['derivative', 'fodder'] in malfeasance
# distance: 0.18613712 	replacing ['since', 'yesterday', 'already', 'almost', 'finally'] in went
# distance: 0.14382952 	replacing ['clean', 'wash'] in dry
# distance: 0.13134822 	replacing ['struggle', 'waste'] in problems
# distance: 0.13050231 	replacing ['action', 'battle'] in challenge
# distance: 0.13167761 	replacing ['screen', 'camera'] in keyboard
# distance: 0.088084355 	replacing ['white', 'black'] in blue
# distance: 0.14012513 	replacing ['china', 'india'] in australia
# distance: 0.13114223 	replacing ['nevertheless', 'amaze'] in nonetheless
# distance: 0.13060571 	replacing ['acceptable', 'appropriate'] in purely
# distance: 0.24770902 	replacing ['soon', 'first', 'whole', 'next', 'another', 'second', 'year', 'every', 'last', 'third'] in this
# distance: 0.12011783 	replacing ['laugh', 'cry'] in hear
# distance: 0.12264988 	replacing ['switch', 'plug'] in lock
# distance: 0.14128639 	replacing ['across', 'near'] in outside
# distance: 0.11645546 	replacing ['dvd', 'cd'] in hd
# distance: 0.14008532 	replacing ['translation', 'dictionary'] in language
# distance: 0.13271642 	replacing ['disappointing', 'frustrating'] in predictable
# distance: 0.14220639 	replacing ['walk', 'around'] in somewhere
# distance: 0.13584258 	replacing ['realistic', 'unrealistic'] in insignificant
# distance: 0.12741414 	replacing ['home', 'house'] in at
# distance: 0.15531808 	replacing ['press', 'release'] in launch
# distance: 0.1341534 	replacing ['legendary', 'superstar'] in singer
# distance: 0.0962739 	replacing ['pack', 'box'] in bag
# distance: 0.13324831 	replacing ['comedy', 'comic'] in movie
# distance: 0.09668453 	replacing ['hardly', 'barely'] in supposed
# distance: 0.113546066 	replacing ['hour', 'early'] in hours
# distance: 0.14381039 	replacing ['stay', 'keep'] in always
# distance: 0.12665173 	replacing ['nintendo', 'playstation'] in nexus
# distance: 0.117537186 	replacing ['interest', 'potential'] in significant
# distance: 0.1399396 	replacing ['age', 'example', 'common'] in difference
# distance: 0.14610064 	replacing ['explain', 'spell'] in understand
# distance: 0.14445907 	replacing ['buy', 'sell'] in free
# distance: 0.1422575 	replacing ['author', 'writer'] in editor
# distance: 0.13378102 	replacing ['quality', 'product'] in includes
# distance: 0.13647193 	replacing ['extraordinary', 'ordinary'] in powerful
# distance: 0.12433514 	replacing ['bluray', 'vhs'] in borderlands
# distance: 0.13503933 	replacing ['break', 'time'] in take
# distance: 0.13042498 	replacing ['enjoy', 'fun'] in good
# Final average Jaccard index: 0.19856494000577565
# CPU times: total: 17min 34s
# Wall time: 18min 4s

# %%
df_2
# Out:
#      Unnamed: 0                                                txt  sentiment
# 0            99  caution!: these tracks are not the "original" ...          0  \
# 1           461  just awful: this was possibly the worst book i...          0
# 2           493  no lessons learned: this is one of the most di...          0
# 3           578  squeem: i ordered according to the size chart ...          0
# 4           595  pass: the sizes run really small, it flips up ...          0
# ..          ...                                                ...        ...
# 941       20710  excellent: prompt delivery. correct parts. you...          1
# 942       20711  purchased minn kota mkp 3 prop from amazon.com...          1
# 943       20738  plantronics bluetooth 665 charger: this charge...          1
# 944       20784  video purchase: like the movie so i bought it....          1
# 945       20790  freakin' funny!!!!!!!!!!!!!!!!!!!!!!!!: if you...          1
#
#      num_of_words                                           anon_txt
# 0              22  caution ! : these track are not the " original...  \
# 1              25  just worse : this was possibly the bad book i ...
# 2              23  no lesson speak : this is one of the most pred...
# 3              21  squeem : i order accord to the size chart for ...
# 4              25  pass : the size run really small , it bag up e...
# ..            ...                                                ...
# 941            24  excellent : prompt delivery . correct secret ....
# 942            25  purchase minn kota mkp 3 prop from amazon.com ...
# 943            28  plantronic bluetooth 665 charger : this charge...
# 944            18  video purchase : like the movie so i free it ....
# 945            20  freakin ' funny ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ...
#
#                                       anon_txt_history
# 0    caution!: (these) {track} (are) (not) (the) "o...
# 1    (just) [worse] (this) (was) possibly (the) {ba...
# 2    (no) {lesson} {learn} (this) (is) one (of) (th...
# 3    squeem: (i) {order} {accord} (to) (the) size c...
# 4    pass: (the) {size} run really small, (it) {fli...
# ..                                                 ...
# 941  excellent: prompt delivery. correct {part} (yo...
# 942  {purchase} minn kota mkp 3 prop (from) amazon....
# 943  {plantronic} bluetooth 665 charger: (this) cha...
# 944  video purchase: like (the) movie (so) (i) {buy...
# 945  {freakin} funny!!!!!!!!!!!!!!!!!!!!!!!!: (if) ...
#
# [946 rows x 6 columns]

# %% [markdown]
# #### 3.2.2) Based on Cosine distance

# %%
# %%time
df_3, word_dict_3 = nlp_utils.replace_words_in_df(df, cluster_dict_cos, dist_dict_cos, threshold, word_dict)
# Out:
# Starting average Jaccard index: 0.18490998931057948
# Distance threshold: 0.3036462366580963
# distance: 0.32705247 the next cluster is too wide and wont be replaced: ['hell', 'four', 'must', 'dumb', 'think', 'although', 'surprised', 'bad', 'mind', 'life', 'whether', 'leave', 'unfortunately', 'give', 'know', 'else', 'day', 'people', 'basically', 'definitely', 'take', 'night', 'apparently', 'dude', 'especially', 'many', 'go', 'well', 'maybe', 'unless', 'turn', 'look', 'sure', 'rather', 'would', 'swear', 'matter', 'however', 'stupid', 'speak', 'obviously', 'forget', 'right', 'might', 'since', 'probably', 'able', 'either', 'need', 'mean', 'enough', 'soon', 'first', 'yesterday', 'make', 'find', 'whole', 'say', 'tell', 'already', 'damn', 'next', 'seriously', 'five', 'today', 'thing', 'hope', 'another', 'anyone', 'guess', 'perhaps', 'certainly', 'something', 'everything', 'ever', 'understand', 'second', 'anymore', 'crazy', 'way', 'nothing', 'much', 'anyway', 'except', 'could', 'see', 'remind', 'wrong', 'year', 'good', 'like', 'pretty', 'remember', 'trust', 'explain', 'possibly', 'though', 'actually', 'exactly', 'almost', 'every', 'yet', 'finally', 'try', 'summer', 'bring', 'totally', 'anything', 'let', 'lot', 'hear', 'reason', 'wonder', 'never', 'really', 'three', 'last', 'always', 'otherwise', 'get', 'expect', 'two', 'still', 'call', 'talk', 'absolutely']
# distance: 0.12038027 	replacing ['fairly', 'somewhat'] in particularly
# distance: 0.13312031 	replacing ['learn', 'teach'] in speak
# distance: 0.118350156 	replacing ['often', 'usually'] in rarely
# distance: 0.13408561 	replacing ['management', 'development'] in strategy
# distance: 0.12321119 	replacing ['ridiculous', 'awful'] in crap
# distance: 0.18078886 	replacing ['fantastic', 'amazing', 'incredible', 'awesome'] in great
# distance: 0.22933029 	replacing ['robert', 'miller', 'johnson', 'joe', 'tony', 'paul', 'clark', 'michael', 'duncan', 'mason', 'carter', 'john', 'smith', 'chandler', 'james'] in lewis
# distance: 0.12183385 	replacing ['definetely', 'definitly', 'definatly'] in definitley
# distance: 0.12112377 	replacing ['instead', 'without'] in while
# distance: 0.17481305 	replacing ['far', 'close', 'away'] in until
# distance: 0.10510028 	replacing ['tongue', 'ear'] in ears
# distance: 0.11806467 	replacing ['cat', 'dog'] in monkey
# distance: 0.12027457 	replacing ['check', 'free'] in new
# distance: 0.08542067 	replacing ['horrible', 'terrible'] in cruel
# distance: 0.18669067 	replacing ['dirty', 'dick', 'ass'] in nasty
# distance: 0.10510544 	replacing ['yeah', 'yes'] in yep
# distance: 0.16536334 	replacing ['brother', 'sister', 'mom', 'friend', 'dad'] in daddy
# distance: 0.08077318 	replacing ['reccommend', 'reccomend'] in somehing
# distance: 0.16544978 	replacing ['mother', 'daughter', 'father', 'wife', 'husband'] in grandpa
# distance: 0.132492 	replacing ['head', 'cut'] in hands
# distance: 0.1908299 	replacing ['l', 'u', 'b', 'r'] in f
# distance: 0.14958885 	replacing ['pls', 'please'] in plz
# distance: 0.16594043 	replacing ['amazingly', 'incredibly', 'extremely'] in insanely
# distance: 0.11401061 	replacing ['british', 'australian'] in canadian
# distance: 0.11439237 	replacing ['sweater', 'jacket'] in hoodie
# distance: 0.10069309 	replacing ['dec', 'oct'] in aug
# distance: 0.13329369 	replacing ['happy', 'birthday'] in thank
# distance: 0.13854446 	replacing ['run', 'hit'] in down
# distance: 0.12257018 	replacing ['drawer', 'shelf'] in storage
# distance: 0.072909445 	replacing ['hahahaha', 'hahaha'] in hahahahaha
# distance: 0.17466207 	replacing ['kid', 'old', 'guy', 'girl'] in like
# distance: 0.10508657 	replacing ['trash', 'garbage'] in dirty
# distance: 0.12302864 	replacing ['brooklyn', 'houston'] in chicago
# distance: 0.088084355 	replacing ['white', 'black'] in blue
# distance: 0.12011783 	replacing ['laugh', 'cry'] in hear
# distance: 0.11645546 	replacing ['dvd', 'cd'] in hd
# distance: 0.17379418 	replacing ['outside', 'walk', 'around'] in somewhere
# distance: 0.12741414 	replacing ['home', 'house'] in at
# distance: 0.0962739 	replacing ['pack', 'box'] in bag
# distance: 0.09668453 	replacing ['hardly', 'barely'] in supposed
# distance: 0.113546066 	replacing ['hour', 'early'] in hours
# distance: 0.14381039 	replacing ['stay', 'keep'] in always
# distance: 0.117537186 	replacing ['interest', 'potential'] in significant
# distance: 0.14445907 	replacing ['buy', 'sell'] in free
# distance: 0.13503933 	replacing ['break', 'time'] in take
# distance: 0.12119682 	replacing ['example', 'common'] in difference
# distance: 0.13042498 	replacing ['enjoy', 'fun'] in good
# Final average Jaccard index: 0.19553817655112876
# CPU times: total: 9min 5s
# Wall time: 10min 14s

# %%
df_3
# Out:
#      Unnamed: 0                                                txt  sentiment
# 0            99  caution!: these tracks are not the "original" ...          0  \
# 1           461  just awful: this was possibly the worst book i...          0
# 2           493  no lessons learned: this is one of the most di...          0
# 3           578  squeem: i ordered according to the size chart ...          0
# 4           595  pass: the sizes run really small, it flips up ...          0
# ..          ...                                                ...        ...
# 941       20710  excellent: prompt delivery. correct parts. you...          1
# 942       20711  purchased minn kota mkp 3 prop from amazon.com...          1
# 943       20738  plantronics bluetooth 665 charger: this charge...          1
# 944       20784  video purchase: like the movie so i bought it....          1
# 945       20790  freakin' funny!!!!!!!!!!!!!!!!!!!!!!!!: if you...          1
#
#      num_of_words                                           anon_txt
# 0              22  caution ! : these track are not the " original...  \
# 1              25  just crap : this was possibly the bad book i h...
# 2              23  no lesson speak : this is one of the most disa...
# 3              21  squeem : i order accord to the size chart for ...
# 4              25  pass : the size down really small , it flip up...
# ..            ...                                                ...
# 941            24  excellent : prompt delivery . correct part . y...
# 942            25  purchase minn kota mkp 3 prop from amazon.com ...
# 943            28  plantronic bluetooth 665 charger : this charge...
# 944            18  video purchase : like the movie so i free it ....
# 945            20  freakin ' funny ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ...
#
#                                       anon_txt_history
# 0    caution!: (these) {track} (are) (not) (the) "o...
# 1    (just) [crap] (this) (was) possibly (the) {bad...
# 2    (no) {lesson} {learn} (this) (is) one (of) (th...
# 3    squeem: (i) {order} {accord} (to) (the) size c...
# 4    pass: (the) {size} [down] really small, (it) {...
# ..                                                 ...
# 941  excellent: prompt delivery. correct {part} (yo...
# 942  {purchase} minn kota mkp 3 prop (from) amazon....
# 943  {plantronic} bluetooth 665 charger: (this) cha...
# 944  video purchase: like (the) movie (so) (i) {buy...
# 945  {freakin} funny!!!!!!!!!!!!!!!!!!!!!!!!: (if) ...
#
# [946 rows x 6 columns]

# %% [markdown]
# #### 3.2.3) Based on HDBSCAN clustering

# %%
# %%time
df_4, word_dict_4 = nlp_utils.replace_words_in_df(df, cluster_dict_h, dist_dict_h, threshold, word_dict)
# Out:
# Starting average Jaccard index: 0.18490998931057948
# Distance threshold: 0.3036462366580963
# distance: 0.33157736 the next cluster is too wide and wont be replaced: ['clifford', 'brown', 'robert', 'christian', 'julia', 'wendy', 'romero', 'ron', 'nick', 'captain', 'abraham', 'joseph', 'perry', 'usher', 'miller', 'gilbert', 'stevie', 'jefferson', 'clint', 'johnson', 'joe', 'jordan', 'reed', 'ann', 'prince', 'courtney', 'albert', 'phillip', 'duke', 'rip', 'christine', 'tony', 'paul', 'mrs', 'clark', 'quentin', 'rebecca', 'keith', 'shin', 'michael', 'turner', 'jack', 'saint', 'gabriel', 'wayne', 'duncan', 'patrick', 'henry', 'mason', 'carter', 'charlie', 'nelly', 'kelly', 'john', 'lisa', 'mr', 'cher', 'smith', 'sung', 'elizabeth', 'chandler', 'julie', 'mario', 'mark', 'james', 'thomas', 'ray']
# distance: 0.3765713 the next cluster is too wide and wont be replaced: ['bean', 'henny', 'cat', 'lamb', 'chocolate', 'recipe', 'tea', 'rice', 'dog', 'cook', 'cake', 'flavor', 'meat', 'food', 'rabbit', 'pet', 'candy', 'coffee', 'delicious', 'yum', 'drink', 'taste', 'soap', 'elephant', 'cereal', 'giant', 'puppy', 'bear', 'oreo']
# distance: 0.3625068 the next cluster is too wide and wont be replaced: ['price', 'delivery', 'bulk', 'shipping', 'account', 'stock', 'suspend', 'card', 'contact', 'mail', 'email', 'purchase', 'available', 'package']
# distance: 0.39657587 the next cluster is too wide and wont be replaced: ['vcr', 'cover', 'series', 'fantasy', 'poster', 'performance', 'visual', 'dvds', 'music', 'audio', 'film', 'glue', 'concert', 'dvd', 'cd', 'amplifier', 'comedy', 'romance', 'song', 'epic', 'cartoon', 'novel', 'album', 'cassette', 'nintendo', 'adventure', 'fps', 'comic', 'ultimate', 'vocal', 'scene', 'dvr', 'bluray', 'japan', 'voice', 'opera', 'video', 'theater', 'radio', 'netflix', 'movie', 'clip', 'official', 'channel', 'version', 'vhs', 'wwe', 'episode']
# distance: 0.31171858 the next cluster is too wide and wont be replaced: ['comedian', 'singer', 'producer', 'legendary', 'mixer', 'dancer', 'superstar']
# distance: 0.36475143 the next cluster is too wide and wont be replaced: ['feature', 'book', 'recording', 'dec', 'scan', 'guest', 'amazon', 'oct', 'chapter', 'modern', 'pdf', 'magazine', 'nov', 'quiz', 'project', 'review']
# distance: 0.3736244 the next cluster is too wide and wont be replaced: ['bike', 'short', 'flow', 'touch', 'solid', 'basic', 'expensive', 'seat', 'set', 'clear', 'cheap', 'air', 'desk', 'extra', 'junk', 'cup', 'clock', 'low', 'fit', 'wave', 'heavy', 'table', 'small', 'edge']
# distance: 0.42650324 the next cluster is too wide and wont be replaced: ['mari', 'k', 'j', 'mel', 'dr', 'l', 'x', 'u', 'c', 'w', 'b', "'", 'g', 'r', 'e', 'ya', 'p', 'co', 'da', 'dd']
# distance: 0.3365844 the next cluster is too wide and wont be replaced: ['fairly', 'utterly', 'highly', 'nicely', 'surprisingly', 'amazingly', 'thoroughly', 'mildly', 'immensely', 'poorly', 'somewhat', 'wonderfully', 'nevertheless', 'impressed', 'socially', 'ecstatic', 'entirely', 'slightly', 'incredibly', 'ridiculously', 'extremely', 'enjoyable', 'horribly']
# distance: 0.35039446 the next cluster is too wide and wont be replaced: ['surprise', 'forward', 'date', 'practice', 'chance', 'couple', 'end']
# distance: 0.38713324 the next cluster is too wide and wont be replaced: ['simple', 'familiar', 'control', 'humor', 'horrible', 'buff', 'plan', 'ego', 'mental', 'moral', 'idea', 'error', 'actual', 'terrible', 'crack', 'total', 'invisible', 'animal', 'produce', 'base']
# distance: 0.40471956 the next cluster is too wide and wont be replaced: ['convey', 'advise', 'often', 'normally', 'quite', 'although', 'solve', 'unfortunately', 'grasp', 'sincerely', 'easily', 'spiritually', 'quickly', 'accurately', 'promptly', 'interpret', 'strongly', 'expose', 'shatter', 'necessary', 'aware', 'careful', 'shy', 'depress', 'recognize', 'inability', 'however', 'refer', 'seem', 'infect', 'entertain', 'arise', 'whatsoever', 'involve', 'hesitate', 'virtually', 'firmly', 'absorb', 'immediately', 'anticipate', 'intend', 'disappoint', 'greatly', 'irritate', 'clarify', 'consider', 'manage', 'insult', 'complicate', 'mislead', 'portray', 'contain', 'frequently', 'therefore', 'grateful', 'satisfied', 'respond', 'soothe', 'indicate', 'likely', 'claim', 'annoy', 'encourage', 'perhaps', 'certainly', 'quicker', 'attach', 'hardly', 'allow', 'steer', 'avoid', 'stumble', 'accomplish', 'confuse', 'beware', 'pity', 'deaf', 'possibly', 'degrade', 'observe', 'difficult', 'unable', 'disturb', 'scare', 'warn', 'continuously', 'distract', 'simply', 'interested', 'usually', 'exaggerate', 'properly', 'accidently', 'truly', 'suggest', 'completely', 'otherwise', 'personally', 'recommend', 'pronounce', 'haunt', 'beyond', 'discuss', 'fully', 'mostly', 'badly', 'happily', 'carefully']
# distance: 0.4157899 the next cluster is too wide and wont be replaced: ['door', 'bright', 'thumb', 'brush', 'gently', 'plastic', 'polyester', 'stud', 'tongue', 'boot', 'purple', 'tear', 'microwave', 'wear', 'charm', 'hand', 'tree', 'hat', 'plain', 'pair', 'ring', 'blue', 'knife', 'diaper', 'tape', 'washer', 'knee', 'hole', 'shrink', 'pocket', 'water', 'coin', 'soft', 'large', 'fabric', 'sand', 'grip', 'chain', 'stick', 'bone', 'ear', 'sweater', 'pattern', 'slips', 'root', 'loose', 'wood', 'copper', 'smell', 'strap', 'drawer', 'tank', 'necklace', 'hair', 'backpack', 'helmet', 'fold', 'clean', 'thin', 'paint', 'shoe', 'white', 'signature', 'wash', 'cut', 'muscle', 'grass', 'tooth', 'green', 'mold', 'holster', 'length', 'slip', 'freezer', 'stamp', 'lamp', 'penny', 'glass', 'shape', 'grain', 'tight', 'toe', 'holder', 'black', 'facial', 'stiff', 'flashlight', 'cotton', 'cheek', 'freeze', 'stink', 'wrap', 'tighten', 'eye', 'box', 'timer', 'lightweight', 'sock', 'scent', 'purse', 'compression', 'tone', 'scratch', 'dry', 'jacket', 'spray', 'string', 'gold', 'dress', 'seed', 'remover', 'bag', 'mask', 'sunscreen', 'compact', 'poop', 'sandal', 'pull', 'burn', 'pajama', 'grab', 'vibrator', 'chew', 'shaft', 'skin', 'cardboard', 'bottom', 'sticky', 'shelf', 'suit', 'cent', 'breeze', 'frame', 'bead', 'resistant', 'dryer', 'pound', 'waterproof', 'shirt']
# distance: 0.366112 the next cluster is too wide and wont be replaced: ['informational', 'defect', 'reveiw', 'discription', 'fodder', 'purport', 'indepth', 'worshipper', 'almanac', 'purchaser', 'orchestration', 'execpt']
# distance: 0.42142892 the next cluster is too wide and wont be replaced: ['digest', 'theory', 'vendor', 'timeless', 'eclectic', 'workbook', 'transaction', 'victorian', 'companion', 'rendition', 'bible', 'surgical', 'shipment', 'literature', 'intermediate', 'bookstore', 'chemistry', 'variety', 'textbook', 'wetness', 'setup', 'outline', 'translation', 'poem', 'childcare', 'poetry', 'alternate', 'landscape', 'symbol', 'instructor', 'dictionary', 'installation', 'essence', 'beginner', 'bilingual', 'retailer', 'document', 'historical', 'reviewer', 'soulful', 'handbook', 'practitioner', 'interactive', 'masterpiece', 'illustration', 'functional', 'mellow', 'instruction', 'reference', 'reception', 'documentation', 'phd', 'buyer', 'autobiography', 'scenery', 'configuration', 'programming']
# distance: 0.24036177 	replacing ['sandler', 'bilbo', 'frankenstein', 'mosby', 'bradbury'] in morrissey
# distance: 0.40332162 the next cluster is too wide and wont be replaced: ['insight', 'peaceful', 'christianity', 'stable', 'saddest', 'inspirational', 'spirituality', 'discipline', 'conclusion', 'magical', 'nightmare', 'romantic', 'valuable', 'creativity', 'savior', 'encounter', 'depth', 'eternal', 'extraordinary', 'ordinary', 'brave', 'mankind', 'thrill', 'wicked']
# distance: 0.36203104 the next cluster is too wide and wont be replaced: ['show', 'star', 'ballet', 'rock', 'dance', 'mud', 'halloween', 'mix', 'bingo', 'live', 'funk', 'tango']
# distance: 0.41798082 the next cluster is too wide and wont be replaced: ['teacher', 'grammar', 'illness', 'rule', 'lack', 'proof', 'anger', 'blessing', 'pleasure', 'determination', 'teaching', 'math', 'topic', 'disappointment', 'human', 'oxygen', 'basis', 'emotion', 'false', 'religious', 'essay', 'damage', 'worthy', 'constitution', 'violent', 'temporary', 'upon', 'happiness', 'disaster', 'joy', 'lifetime', 'english', 'term', 'experience', 'strange', 'test', 'goodness', 'opportunity', 'prayer', 'algebra', 'concern', 'growth', 'pain', 'political', 'religion', 'lesson', 'majority', 'silence', 'science', 'excitement', 'negative', 'impose', 'grace', 'talent', 'meaning', 'interest', 'age', 'congress', 'value', 'condition', 'potential', 'foreign', 'lord', 'purpose', 'option', 'society', 'sentence', 'suicide', 'subject', 'freedom', 'speech', 'violence', 'apology', 'severe', 'example', 'sight', 'common', 'generation', 'benefit', 'response', 'professor']
# distance: 0.39853087 the next cluster is too wide and wont be replaced: ['offer', 'focus', 'exercise', 'grade', 'recieve']
# distance: 0.40886593 the next cluster is too wide and wont be replaced: ['sense', 'teenager', 'correct', 'opinion', 'create', 'assume', 'mistake', 'realist', 'compare', 'resolve', 'attitude', 'define', 'discover']
# distance: 0.3658118 the next cluster is too wide and wont be replaced: ['management', 'content', 'board', 'section', 'research', 'fund', 'information', 'travel', 'education', 'client', 'leader', 'medical', 'retail', 'office', 'industry', 'unit', 'safety', 'application', 'press', 'exchange', 'access', 'bill', 'software', 'daily', 'group', 'gbp', 'library', 'customer', 'business', 'development', 'search', 'service', 'rental', 'company', 'agency', 'student', 'guide', 'view', 'elementary', 'program', 'hike']
# distance: 0.3159378 the next cluster is too wide and wont be replaced: ['ridiculous', 'crappy', 'typical', 'awful', 'peeve', 'irrelevant', 'useless', 'relevant', 'proper', 'pointless', 'rubbish', 'worthless', 'decent']
# distance: 0.39899388 the next cluster is too wide and wont be replaced: ['share', 'mention', 'check', 'exit', 'new', 'spread', 'open', 'remove', 'promote', 'pass', 'trick', 'delete', 'free', 'number', 'ship', 'save', 'charge', 'buy', 'send', 'sell', 'gain', 'reach', 'replace']
# distance: 0.30011117 	replacing ['worth', 'instead', 'happen', 'mind', 'else', 'alot', 'worse', 'people', 'especially', 'someone', 'unless', 'lose', 'none', 'without', 'whoever', 'matter', 'spend', 'either', 'enough', 'find', 'shame', 'anyone', 'sometimes', 'something', 'everything', 'understand', 'suppose', 'anymore', 'nothing', 'care', 'except', 'everyone', 'poor', 'remind', 'wrong', 'person', 'trust', 'exactly', 'truth', 'anything', 'lot', 'reason', 'anywhere'] in means
# distance: 0.35638845 the next cluster is too wide and wont be replaced: ['freakin', 'bet', 'wish', 'yeah', 'dude', 'ok', 'stupid', 'hahahaha', 'wow', 'damn', 'hope', 'bit', 'wtf', 'crazy', 'hahaha', 'kinda', 'yes', 'okay', 'sorry', 'chill', 'huh', 'yea']
# distance: 0.39235157 the next cluster is too wide and wont be replaced: ['belkin', 'mandolin', 'toxicity', 'rattle', 'nomad', 'psi', 'stargate', 'cavalier', 'bose', 'motorcyclist', 'ecru', 'supersonic', 'cq', 'dorman', 'ransom']
# distance: 0.4101195 the next cluster is too wide and wont be replaced: ['noose', 'wart', 'girdle', 'handkerchief', 'toenail', 'crumpet', 'rotate', 'fasten', 'splint', 'earing', 'undershirt', 'lanyard', 'scratcher', 'opend', 'wasteof', 'halti', 'spanx', 'drippy', 'thickest']
# distance: 0.33312464 the next cluster is too wide and wont be replaced: ['middle', 'deep', 'sunny', 'ride', 'fire', 'road', 'moon', 'ground', 'rain', 'snow', 'side', 'across', 'lane', 'sun', 'front', 'shine', 'beach', 'near']
# distance: 0.4189085 the next cluster is too wide and wont be replaced: ['tomcat', 'adress', 'gad', 'zzzzzz', 'wase', 'enoy', 'agan', 'rut', 'iti', 'dud', 'thia', 'ime', 'compaire', 'mog', 'congrat', 'zuk', 'mule', 'doone', 'minn', 'aal', 'muni', 'charle', 'soso', 'pamer', 'slog', 'morrillo', 'anake', 'itit', 'jule', 'wep', 'iii', 'waas', 'addy']
# distance: 0.357017 the next cluster is too wide and wont be replaced: ['reliable', 'upbeat', 'insightful', 'informative', 'energetic', 'profound', 'intriguing', 'realistic', 'inexpensive', 'convenient', 'helpful', 'imaginative', 'unrealistic', 'reasonable', 'misfortune']
# distance: 0.3234995 the next cluster is too wide and wont be replaced: ['monitor', 'repair', 'volume', 'paste', 'engine']
# distance: 0.36415663 the next cluster is too wide and wont be replaced: ['soldier', 'border', 'egyptian', 'shia', 'catholic', 'portuguese', 'iraqi', 'occupy', 'amish']
# distance: 0.37703925 the next cluster is too wide and wont be replaced: ['long', 'month', 'safe', 'day', 'night', 'rest', 'pls', 'ago', 'nearly', 'amazing', 'til', 'awesome', 'since', 'yesterday', 'whole', 'half', 'mood', 'next', 'dream', 'today', 'nap', 'great', 'year', 'hour', 'week', 'school', 'summer', 'slow', 'time', 'bf', 'later', 'christmas', 'last', 'twice', 'early', 'text', 'past', 'enjoy', 'fun']
# distance: 0.35377207 the next cluster is too wide and wont be replaced: ['disparage', 'recomend', 'watchig', 'reaffirm', 'annotate', 'discontinue', 'overprice', 'transcribe']
# distance: 0.3827826 the next cluster is too wide and wont be replaced: ['bothersome', 'producti', 'generalization', 'unimaginative', 'actionmovie', 'unsupported', 'insipid', 'flavorless', 'implausible', 'comprehensible', 'allegory', 'vacuous', 'distasteful', 'aweful', 'talente', 'suspenseful', 'synch', 'trite', 'goodi', 'grat', 'disapointment', 'unreadable', 'listenable', 'waster', 'nonexistant', 'critism', 'forgettable', 'cheep', 'myopic', 'recommendable', 'foreshadow', 'induce', 'capitalistic']
# distance: 0.33776808 the next cluster is too wide and wont be replaced: ['leave', 'give', 'know', 'take', 'stop', 'come', 'put', 'go', 'alone', 'well', 'believe', 'tired', 'maybe', 'sure', 'back', 'feeling', 'forget', 'nothin', 'right', 'need', 'cause', 'hard', 'laugh', 'make', 'hate', 'say', 'tell', 'seriously', 'man', 'thing', 'listen', 'even', 'guess', 'want', 'ever', 'see', 'stay', 'remember', 'though', 'feel', 'bring', 'sum', 'keep', 'let', 'hear', 'cry', 'sad', 'wonder', 'forever', 'never', 'always', 'get', 'one', 'still', 'call', 'fool', 'talk', 'sleep']
# distance: 0.33482343 the next cluster is too wide and wont be replaced: ['gerson', 'aiken', 'morillo', 'lightfoot', 'carnegie', 'caspian', 'karyn', 'caine', 'langston', 'quigley', 'boyer', 'garwood', 'ryu', 'asimov', 'bozo', 'verne', 'devlin', 'wiley', 'jonestown', 'browne', 'lore', 'constantine', 'paxton', 'bunyan', 'sherryl', 'myer', 'phelan', 'sherry', 'kerouac', 'coltrane', 'cornwell']
# distance: 0.25680813 	replacing ['thru', 'turn', 'hold', 'run', 'straight', 'hit', 'beat', 'fall', 'catch', 'kick', 'fight'] in down
# distance: 0.516498 the next cluster is too wide and wont be replaced: ['pos', 'dale', 'dice', 'sea', 'mono', 'sale', 'ti', 'son', 'al', 'vista', 'va', 'favor', 'gane', 'van', 'senti', 'tenia', 'uf', 'vale', 'primer']
# distance: 0.42462578 the next cluster is too wide and wont be replaced: ['transformer', 'cage', 'collar', 'pote', 'tube', 'cave', 'wil', 'xs']
# distance: 0.36065754 the next cluster is too wide and wont be replaced: ['league', 'title', 'selection', 'franchise', 'info', 'player', 'battle', 'hockey']
# distance: 0.32720593 the next cluster is too wide and wont be replaced: ['interesting', 'unbelievable', 'incredible', 'prediction', 'clever', 'competitive', 'overall', 'superb', 'outstanding', 'duper', 'terrific', 'appropriate', 'brilliant', 'impressive', 'frustrating']
# distance: 0.289588 	replacing ['sign', 'fair', 'support', 'third'] in for
# distance: 0.31737304 the next cluster is too wide and wont be replaced: ['name', 'brother', 'sister', 'mother', 'daughter', 'mom', 'kid', 'marry', 'old', 'woman', 'friend', 'adorable', 'guy', 'father', 'nephew', 'wife', 'cute', 'boyfriend', 'baby', 'little', 'husband', 'child', 'girl', 'picture', 'dad']
# distance: 0.3693341 the next cluster is too wide and wont be replaced: ['kit', 'custom', 'canon', 'pc', 'samsung', 'bluetooth', 'tablet', 'print', 'xl', 'desktop', 'multi', 'item', 'authentic', 'auto', 'ipad']
# distance: 0.27490008 	replacing ['relationship', 'speak', 'treat'] in care
# distance: 0.39422908 the next cluster is too wide and wont be replaced: ['pun', 'meet', 'happy', 'dear', 'thank', 'bye']
# distance: 0.37551686 the next cluster is too wide and wont be replaced: ['british', 'america', 'state', 'china', 'area', 'center', 'india', 'mexico', 'american', 'houston', 'birmingham', 'coast', 'german', 'thailand', 'city', 'sf', 'western', 'uk', 'country', 'australian', 'south', 'kota']
# distance: 0.49051535 the next cluster is too wide and wont be replaced: ['storie', 'laminator', 'pinyin', 'trekkie']
# distance: 0.38876027 the next cluster is too wide and wont be replaced: ['complete', 'ton', 'plus']
# Final average Jaccard index: 0.19268306551198777
# CPU times: total: 8min 44s
# Wall time: 9min 17s

# %%
df_4
# Out:
#      Unnamed: 0                                                txt  sentiment
# 0            99  caution!: these tracks are not the "original" ...          0  \
# 1           461  just awful: this was possibly the worst book i...          0
# 2           493  no lessons learned: this is one of the most di...          0
# 3           578  squeem: i ordered according to the size chart ...          0
# 4           595  pass: the sizes run really small, it flips up ...          0
# ..          ...                                                ...        ...
# 941       20710  excellent: prompt delivery. correct parts. you...          1
# 942       20711  purchased minn kota mkp 3 prop from amazon.com...          1
# 943       20738  plantronics bluetooth 665 charger: this charge...          1
# 944       20784  video purchase: like the movie so i bought it....          1
# 945       20790  freakin' funny!!!!!!!!!!!!!!!!!!!!!!!!: if you...          1
#
#      num_of_words                                           anon_txt
# 0              22  caution ! : these track are not the " original...  \
# 1              25  just awful : this was possibly the bad book i ...
# 2              23  no lesson learn : this is one of the most disa...
# 3              21  squeem : i order accord to the size chart for ...
# 4              25  pass : the size down really small , it flip up...
# ..            ...                                                ...
# 941            24  excellent : prompt delivery . correct part . y...
# 942            25  purchase minn kota mkp 3 prop from amazon.com ...
# 943            28  plantronic bluetooth 665 charger : this charge...
# 944            18  video purchase : like the movie so i buy it . ...
# 945            20  freakin ' funny ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ...
#
#                                       anon_txt_history
# 0    caution!: (these) {track} (are) (not) (the) "o...
# 1    (just) [crap] (this) (was) possibly (the) {bad...
# 2    (no) {lesson} {learn} (this) (is) one (of) (th...
# 3    squeem: (i) {order} {accord} (to) (the) size c...
# 4    pass: (the) {size} [down] really small, (it) {...
# ..                                                 ...
# 941  excellent: prompt delivery. correct {part} (yo...
# 942  {purchase} minn kota mkp 3 prop (from) amazon....
# 943  {plantronic} bluetooth 665 charger: (this) cha...
# 944  video purchase: like (the) movie (so) (i) {buy...
# 945  {freakin} funny!!!!!!!!!!!!!!!!!!!!!!!!: (if) ...
#
# [946 rows x 6 columns]

# %% [markdown]
# For eucledian distance

# %%
protected, lemma, replaced, all = nlp_utils.get_stat(word_dict_2)
print(f'Protected: {protected}\tLemmatized: {lemma}\t Replaced: {replaced}\t All: {all}')
# Out:
# Protected: 135	Lemmatized: 970	 Replaced: 350	 All: 3311

# %% [markdown]
# Looking at the histogram again

# %%
# %%time
nlp_utils.plot_jaccard_hist(df_2, column='txt')
# Out:
# CPU times: total: 7.73 s
# Wall time: 7.97 s

# %%
# %%time
nlp_utils.plot_jaccard_hist(df_2, 'anon_txt')
# Out:
# CPU times: total: 7.94 s
# Wall time: 8.15 s

# %%
print('Eucolidian dist:\t', df_2.iloc[3, 4])
print('Cosine dist:\t\t', df_3.iloc[3, 4])
print('HDNSCAN:\t\t', df_4.iloc[3, 4])
# Out:
# Eucolidian dist:	 squeem : i order accord to the size chart for my measurement and it was way to small ! ! very uncomfortable.i return it ,
# Cosine dist:		 squeem : i order accord to the size chart for my measurement and it was way to small ! ! very uncomfortable.i return it ,
# HDNSCAN:		 squeem : i order accord to the size chart for my measurement and it was way to small ! ! very uncomfortable.i return it ,

# %%
nlp_utils.get_stat(word_dict_2)
# Out:
# (135, 970, 350, 3311)

# %% [markdown]
# ## 4) Force anonymity

# %% [markdown]
# ### Get anonymity degree

# %% [markdown]
# Before replacement

# %%
curr_k, non_anon_indexes = anonym_utils.get_anonym_degree(docs=df_2['txt'])
print('Current k:', curr_k, '\tnumber of un-anonym. documents:', len(non_anon_indexes), '\tnumber of all documents:', len(df_2['txt']))
# Out:
# Current k: 1 	number of un-anonym. documents: 944 	number of all documents: 946

# %% [markdown]
# After replacement

# %%
curr_k, non_anon_indexes = anonym_utils.get_anonym_degree(docs=df_2['anon_txt'])
print('Current k:', curr_k, '\tnumber of un-anonym. documents:', len(non_anon_indexes), '\tnumber of all documents:', len(df_2['anon_txt']))
# Out:
# Current k: 1 	number of un-anonym. documents: 944 	number of all documents: 946

# %% [markdown]
# ### Steps:
# 1. Finding k nearest neighbors using approximate nearest neighbors
# 2. Finding the different words between the neighbors
# 2. Replacing the different words with *

# %%
anonym_utils.delete_uncommon_words(['I love choco', 'I love banana'])
# Out:
# ['I love *', 'I love *']

# %%
anonym_utils.force_anonym_using_annoy(['I love choco', 'I love banana', 'lalala'], k=2)
# Out:
# Start: get_anonym_degree: 1
# similar_doc_ind [0, 1]
# Breaking! 	len(used_indexes) 2 	len(docs) 3 	len(docs)-k 1
# unused_indexes: [2]
# End: get_anonym_degree: 1
# ['I love *', 'I love *', '*']

# %%
force_anon_txt_annoy = anonym_utils.force_anonym_using_annoy(df_2['anon_txt'], k=2)
anonym_utils.get_anonym_degree(force_anon_txt_annoy)
# Out:
# Start: get_anonym_degree: 1
# similar_doc_ind [0, 298]
# similar_doc_ind [1, 265]
# similar_doc_ind [2, 754]
# similar_doc_ind [3, 246]
# similar_doc_ind [4, 534]
# similar_doc_ind [5, 876]
# similar_doc_ind [6, 228]
# similar_doc_ind [7, 424]
# similar_doc_ind [8, 220]
# similar_doc_ind [9, 771]
# similar_doc_ind [10, 12]
# similar_doc_ind [11, 369]
# similar_doc_ind [13, 384]
# similar_doc_ind [14, 408]
# similar_doc_ind [15, 314]
# similar_doc_ind [16, 231]
# similar_doc_ind [17, 374]
# similar_doc_ind [18, 385]
# similar_doc_ind [19, 370]
# similar_doc_ind [20, 213]
# similar_doc_ind [21, 355]
# similar_doc_ind [22, 581]
# similar_doc_ind [23, 784]
# similar_doc_ind [24, 728]
# similar_doc_ind [25, 372]
# similar_doc_ind [26, 140]
# similar_doc_ind [27, 653]
# similar_doc_ind [28, 143]
# similar_doc_ind [29, 77]
# similar_doc_ind [30, 516]
# similar_doc_ind [31, 159]
# similar_doc_ind [32, 34]
# similar_doc_ind [33, 436]
# similar_doc_ind [35, 40]
# similar_doc_ind [36, 615]
# similar_doc_ind [37, 590]
# similar_doc_ind [38, 501]
# similar_doc_ind [39, 287]
# similar_doc_ind [41, 196]
# similar_doc_ind [42, 236]
# similar_doc_ind [43, 84]
# similar_doc_ind [44, 161]
# similar_doc_ind [45, 284]
# similar_doc_ind [46, 138]
# similar_doc_ind [47, 354]
# similar_doc_ind [48, 269]
# similar_doc_ind [49, 72]
# similar_doc_ind [50, 248]
# similar_doc_ind [51, 94]
# similar_doc_ind [52, 792]
# similar_doc_ind [53, 388]
# similar_doc_ind [54, 154]
# similar_doc_ind [55, 801]
# similar_doc_ind [56, 571]
# similar_doc_ind [57, 685]
# similar_doc_ind [58, 539]
# similar_doc_ind [59, 776]
# similar_doc_ind [60, 667]
# similar_doc_ind [61, 898]
# similar_doc_ind [62, 498]
# similar_doc_ind [63, 185]
# similar_doc_ind [64, 924]
# similar_doc_ind [65, 83]
# similar_doc_ind [66, 646]
# similar_doc_ind [67, 192]
# similar_doc_ind [68, 219]
# similar_doc_ind [69, 194]
# similar_doc_ind [70, 303]
# similar_doc_ind [71, 74]
# similar_doc_ind [73, 243]
# similar_doc_ind [75, 439]
# similar_doc_ind [76, 203]
# similar_doc_ind [78, 555]
# similar_doc_ind [79, 645]
# similar_doc_ind [80, 888]
# similar_doc_ind [81, 190]
# similar_doc_ind [82, 855]
# similar_doc_ind [85, 227]
# similar_doc_ind [86, 895]
# similar_doc_ind [87, 515]
# similar_doc_ind [88, 576]
# similar_doc_ind [89, 268]
# similar_doc_ind [90, 98]
# similar_doc_ind [91, 429]
# similar_doc_ind [92, 244]
# similar_doc_ind [93, 930]
# similar_doc_ind [95, 151]
# similar_doc_ind [96, 400]
# similar_doc_ind [97, 207]
# similar_doc_ind [99, 391]
# similar_doc_ind [100, 403]
# similar_doc_ind [101, 320]
# similar_doc_ind [102, 311]
# similar_doc_ind [103, 115]
# similar_doc_ind [104, 907]
# similar_doc_ind [105, 425]
# similar_doc_ind [106, 755]
# similar_doc_ind [107, 266]
# similar_doc_ind [108, 395]
# similar_doc_ind [109, 730]
# similar_doc_ind [110, 165]
# similar_doc_ind [111, 417]
# similar_doc_ind [112, 525]
# similar_doc_ind [113, 839]
# similar_doc_ind [114, 441]
# similar_doc_ind [116, 184]
# similar_doc_ind [117, 218]
# similar_doc_ind [118, 183]
# similar_doc_ind [119, 318]
# similar_doc_ind [120, 136]
# similar_doc_ind [121, 509]
# similar_doc_ind [122, 137]
# similar_doc_ind [123, 150]
# similar_doc_ind [124, 393]
# similar_doc_ind [125, 640]
# similar_doc_ind [126, 703]
# similar_doc_ind [127, 302]
# similar_doc_ind [128, 193]
# similar_doc_ind [129, 214]
# similar_doc_ind [130, 648]
# similar_doc_ind [131, 132]
# similar_doc_ind [133, 702]
# similar_doc_ind [134, 698]
# similar_doc_ind [135, 697]
# similar_doc_ind [139, 402]
# similar_doc_ind [141, 274]
# similar_doc_ind [142, 191]
# similar_doc_ind [144, 174]
# similar_doc_ind [145, 255]
# similar_doc_ind [146, 254]
# similar_doc_ind [147, 363]
# similar_doc_ind [148, 474]
# similar_doc_ind [149, 478]
# similar_doc_ind [152, 153]
# similar_doc_ind [155, 433]
# similar_doc_ind [156, 736]
# similar_doc_ind [157, 738]
# similar_doc_ind [158, 253]
# similar_doc_ind [160, 252]
# similar_doc_ind [162, 257]
# similar_doc_ind [163, 459]
# similar_doc_ind [164, 808]
# similar_doc_ind [166, 880]
# similar_doc_ind [167, 860]
# similar_doc_ind [168, 782]
# similar_doc_ind [169, 612]
# similar_doc_ind [170, 378]
# similar_doc_ind [171, 204]
# similar_doc_ind [172, 816]
# similar_doc_ind [173, 587]
# similar_doc_ind [175, 347]
# similar_doc_ind [176, 241]
# similar_doc_ind [177, 599]
# similar_doc_ind [178, 625]
# similar_doc_ind [179, 879]
# similar_doc_ind [180, 396]
# similar_doc_ind [181, 861]
# similar_doc_ind [182, 264]
# similar_doc_ind [186, 671]
# similar_doc_ind [187, 554]
# similar_doc_ind [188, 722]
# similar_doc_ind [189, 659]
# similar_doc_ind [195, 337]
# similar_doc_ind [197, 829]
# similar_doc_ind [198, 449]
# similar_doc_ind [199, 931]
# similar_doc_ind [200, 211]
# similar_doc_ind [201, 331]
# similar_doc_ind [202, 313]
# similar_doc_ind [205, 249]
# similar_doc_ind [206, 352]
# similar_doc_ind [208, 304]
# similar_doc_ind [209, 908]
# similar_doc_ind [210, 578]
# similar_doc_ind [212, 239]
# similar_doc_ind [215, 277]
# similar_doc_ind [216, 682]
# similar_doc_ind [217, 766]
# similar_doc_ind [221, 604]
# similar_doc_ind [222, 825]
# similar_doc_ind [223, 819]
# similar_doc_ind [224, 413]
# similar_doc_ind [225, 626]
# similar_doc_ind [226, 629]
# similar_doc_ind [229, 230]
# similar_doc_ind [232, 715]
# similar_doc_ind [233, 333]
# similar_doc_ind [234, 795]
# similar_doc_ind [235, 557]
# similar_doc_ind [237, 779]
# similar_doc_ind [238, 329]
# similar_doc_ind [240, 316]
# similar_doc_ind [242, 364]
# similar_doc_ind [245, 346]
# similar_doc_ind [247, 334]
# similar_doc_ind [250, 877]
# similar_doc_ind [251, 595]
# similar_doc_ind [256, 462]
# similar_doc_ind [258, 379]
# similar_doc_ind [259, 639]
# similar_doc_ind [260, 812]
# similar_doc_ind [261, 710]
# similar_doc_ind [262, 660]
# similar_doc_ind [263, 398]
# similar_doc_ind [267, 622]
# similar_doc_ind [270, 271]
# similar_doc_ind [272, 708]
# similar_doc_ind [273, 411]
# similar_doc_ind [275, 368]
# similar_doc_ind [276, 297]
# similar_doc_ind [278, 672]
# similar_doc_ind [279, 650]
# similar_doc_ind [280, 886]
# similar_doc_ind [281, 883]
# similar_doc_ind [282, 324]
# similar_doc_ind [283, 448]
# similar_doc_ind [285, 568]
# similar_doc_ind [286, 847]
# similar_doc_ind [288, 764]
# similar_doc_ind [289, 375]
# similar_doc_ind [290, 414]
# similar_doc_ind [291, 438]
# similar_doc_ind [292, 532]
# similar_doc_ind [293, 600]
# similar_doc_ind [294, 465]
# similar_doc_ind [295, 467]
# similar_doc_ind [296, 741]
# similar_doc_ind [299, 445]
# similar_doc_ind [300, 938]
# similar_doc_ind [301, 529]
# similar_doc_ind [305, 837]
# similar_doc_ind [306, 319]
# similar_doc_ind [307, 585]
# similar_doc_ind [308, 749]
# similar_doc_ind [309, 933]
# similar_doc_ind [310, 637]
# similar_doc_ind [312, 361]
# similar_doc_ind [315, 665]
# similar_doc_ind [317, 356]
# similar_doc_ind [321, 654]
# similar_doc_ind [322, 406]
# similar_doc_ind [323, 828]
# similar_doc_ind [325, 928]
# similar_doc_ind [326, 418]
# similar_doc_ind [327, 502]
# similar_doc_ind [328, 817]
# similar_doc_ind [330, 442]
# similar_doc_ind [332, 681]
# similar_doc_ind [335, 527]
# similar_doc_ind [336, 357]
# similar_doc_ind [338, 773]
# similar_doc_ind [339, 594]
# similar_doc_ind [340, 690]
# similar_doc_ind [341, 717]
# similar_doc_ind [342, 495]
# similar_doc_ind [343, 491]
# similar_doc_ind [344, 815]
# similar_doc_ind [345, 679]
# similar_doc_ind [348, 536]
# similar_doc_ind [349, 553]
# similar_doc_ind [350, 377]
# similar_doc_ind [351, 897]
# similar_doc_ind [353, 592]
# similar_doc_ind [358, 422]
# similar_doc_ind [359, 360]
# similar_doc_ind [362, 875]
# similar_doc_ind [365, 542]
# similar_doc_ind [366, 862]
# similar_doc_ind [367, 811]
# similar_doc_ind [371, 896]
# similar_doc_ind [373, 868]
# similar_doc_ind [376, 421]
# similar_doc_ind [380, 870]
# similar_doc_ind [381, 382]
# similar_doc_ind [383, 611]
# similar_doc_ind [386, 937]
# similar_doc_ind [387, 664]
# similar_doc_ind [389, 740]
# similar_doc_ind [390, 437]
# similar_doc_ind [392, 762]
# similar_doc_ind [394, 602]
# similar_doc_ind [397, 689]
# similar_doc_ind [399, 489]
# similar_doc_ind [401, 867]
# similar_doc_ind [404, 564]
# similar_doc_ind [405, 891]
# similar_doc_ind [407, 431]
# similar_doc_ind [409, 589]
# similar_doc_ind [410, 451]
# similar_doc_ind [412, 641]
# similar_doc_ind [415, 606]
# similar_doc_ind [416, 430]
# similar_doc_ind [419, 921]
# similar_doc_ind [420, 753]
# similar_doc_ind [423, 457]
# similar_doc_ind [426, 447]
# similar_doc_ind [427, 597]
# similar_doc_ind [428, 572]
# similar_doc_ind [432, 797]
# similar_doc_ind [434, 508]
# similar_doc_ind [435, 668]
# similar_doc_ind [440, 850]
# similar_doc_ind [443, 854]
# similar_doc_ind [444, 466]
# similar_doc_ind [446, 911]
# similar_doc_ind [450, 652]
# similar_doc_ind [452, 619]
# similar_doc_ind [453, 632]
# similar_doc_ind [454, 841]
# similar_doc_ind [455, 620]
# similar_doc_ind [456, 807]
# similar_doc_ind [458, 623]
# similar_doc_ind [460, 887]
# similar_doc_ind [461, 506]
# similar_doc_ind [463, 739]
# similar_doc_ind [464, 535]
# similar_doc_ind [468, 680]
# similar_doc_ind [469, 772]
# similar_doc_ind [470, 621]
# similar_doc_ind [471, 593]
# similar_doc_ind [472, 475]
# similar_doc_ind [473, 523]
# similar_doc_ind [476, 709]
# similar_doc_ind [477, 725]
# similar_doc_ind [479, 573]
# similar_doc_ind [480, 793]
# similar_doc_ind [481, 583]
# similar_doc_ind [482, 575]
# similar_doc_ind [483, 618]
# similar_doc_ind [484, 582]
# similar_doc_ind [485, 729]
# similar_doc_ind [486, 830]
# similar_doc_ind [487, 790]
# similar_doc_ind [488, 878]
# similar_doc_ind [490, 791]
# similar_doc_ind [492, 607]
# similar_doc_ind [493, 760]
# similar_doc_ind [494, 510]
# similar_doc_ind [496, 533]
# similar_doc_ind [497, 866]
# similar_doc_ind [499, 932]
# similar_doc_ind [500, 548]
# similar_doc_ind [503, 649]
# similar_doc_ind [504, 842]
# similar_doc_ind [505, 550]
# similar_doc_ind [507, 810]
# similar_doc_ind [511, 656]
# similar_doc_ind [512, 713]
# similar_doc_ind [513, 744]
# similar_doc_ind [514, 628]
# similar_doc_ind [517, 635]
# similar_doc_ind [518, 737]
# similar_doc_ind [519, 853]
# similar_doc_ind [520, 726]
# similar_doc_ind [521, 865]
# similar_doc_ind [522, 834]
# similar_doc_ind [524, 673]
# similar_doc_ind [526, 647]
# similar_doc_ind [528, 864]
# similar_doc_ind [530, 780]
# similar_doc_ind [531, 601]
# similar_doc_ind [537, 840]
# similar_doc_ind [538, 871]
# similar_doc_ind [540, 756]
# similar_doc_ind [541, 676]
# similar_doc_ind [543, 691]
# similar_doc_ind [544, 633]
# similar_doc_ind [545, 758]
# similar_doc_ind [546, 707]
# similar_doc_ind [547, 644]
# similar_doc_ind [549, 863]
# similar_doc_ind [551, 569]
# similar_doc_ind [552, 574]
# similar_doc_ind [556, 591]
# similar_doc_ind [558, 922]
# similar_doc_ind [559, 630]
# similar_doc_ind [560, 889]
# similar_doc_ind [561, 767]
# similar_doc_ind [562, 820]
# similar_doc_ind [563, 893]
# similar_doc_ind [565, 670]
# similar_doc_ind [566, 789]
# similar_doc_ind [567, 613]
# similar_doc_ind [570, 919]
# similar_doc_ind [577, 614]
# similar_doc_ind [579, 742]
# similar_doc_ind [580, 936]
# similar_doc_ind [584, 925]
# similar_doc_ind [586, 909]
# similar_doc_ind [588, 761]
# similar_doc_ind [596, 699]
# similar_doc_ind [598, 882]
# similar_doc_ind [603, 605]
# similar_doc_ind [608, 759]
# similar_doc_ind [609, 827]
# similar_doc_ind [610, 785]
# similar_doc_ind [616, 768]
# similar_doc_ind [617, 885]
# similar_doc_ind [624, 662]
# similar_doc_ind [627, 727]
# similar_doc_ind [631, 901]
# similar_doc_ind [634, 858]
# similar_doc_ind [636, 844]
# similar_doc_ind [638, 914]
# similar_doc_ind [642, 724]
# similar_doc_ind [643, 800]
# similar_doc_ind [651, 814]
# similar_doc_ind [655, 813]
# similar_doc_ind [657, 941]
# similar_doc_ind [658, 904]
# similar_doc_ind [661, 836]
# similar_doc_ind [663, 939]
# similar_doc_ind [666, 806]
# similar_doc_ind [669, 809]
# similar_doc_ind [674, 915]
# similar_doc_ind [675, 695]
# similar_doc_ind [677, 687]
# similar_doc_ind [678, 743]
# similar_doc_ind [683, 788]
# similar_doc_ind [684, 918]
# similar_doc_ind [686, 783]
# similar_doc_ind [688, 903]
# similar_doc_ind [692, 923]
# similar_doc_ind [693, 705]
# similar_doc_ind [694, 823]
# similar_doc_ind [696, 940]
# similar_doc_ind [700, 751]
# similar_doc_ind [701, 934]
# similar_doc_ind [704, 835]
# similar_doc_ind [706, 802]
# similar_doc_ind [711, 714]
# similar_doc_ind [712, 843]
# similar_doc_ind [716, 803]
# similar_doc_ind [718, 832]
# similar_doc_ind [719, 822]
# similar_doc_ind [720, 910]
# similar_doc_ind [721, 852]
# similar_doc_ind [723, 944]
# similar_doc_ind [731, 805]
# similar_doc_ind [732, 733]
# similar_doc_ind [734, 851]
# similar_doc_ind [735, 752]
# similar_doc_ind [745, 799]
# similar_doc_ind [746, 787]
# similar_doc_ind [747, 913]
# similar_doc_ind [748, 821]
# similar_doc_ind [750, 838]
# similar_doc_ind [757, 905]
# similar_doc_ind [763, 778]
# similar_doc_ind [765, 920]
# similar_doc_ind [769, 774]
# similar_doc_ind [770, 798]
# similar_doc_ind [775, 845]
# similar_doc_ind [777, 818]
# similar_doc_ind [781, 833]
# similar_doc_ind [786, 894]
# similar_doc_ind [794, 929]
# similar_doc_ind [796, 890]
# similar_doc_ind [804, 856]
# similar_doc_ind [824, 874]
# similar_doc_ind [826, 869]
# similar_doc_ind [831, 859]
# similar_doc_ind [846, 935]
# similar_doc_ind [848, 884]
# similar_doc_ind [849, 881]
# similar_doc_ind [857, 943]
# similar_doc_ind [872, 942]
# similar_doc_ind [873, 917]
# similar_doc_ind [892, 906]
# similar_doc_ind [899, 902]
# similar_doc_ind [900, 926]
# similar_doc_ind [912, 916]
# similar_doc_ind [927, 945]
# Breaking! 	len(used_indexes) 946 	len(docs) 946 	len(docs)-k 944
# unused_indexes: []
# End: get_anonym_degree: 1
# (1, [[705], [693], [916], [134], [698], [133], [702]])

# %%
print([693, 705])
print(df_2['anon_txt'][693])
print(force_anon_txt_annoy[693])
print()
print(df_2['anon_txt'][705])
print(force_anon_txt_annoy[705])
# Out:
# [693, 705]
# pamper : what a life saver . i order these for my grandfather and they save me take and money . i would purchase again
# pamper : what a * * . i * these for my * and they * me take and * . i * * again
#
# great trade ! ! : great trade ! ! they arrive in less take than quote to my door ! you just can not go wrong with pamper and i am love amazon ! ! :)
# * * ! ! : * * ! ! they * in * take than * to my * ! you just can not * * with pamper and i am * * ! ! :)

# %%
arr, voc = anonym_utils.get_bow([force_anon_txt_annoy[693], force_anon_txt_annoy[705]])
print(voc)
print(arr.toarray())
# Out:
# ['pamper' 'take']
# [[1 1]
#  [1 1]]

# %%
df_2['force_anon_txt'] = force_anon_txt_annoy

# %% [markdown]
# ## 5) Utilization tests

# %%
df_21 = utilization_utils.get_vader_sentiment_for_df(df_2, ['txt', 'anon_txt', 'force_anon_txt'])
df_21
# Out:
#      Unnamed: 0                                                txt  sentiment
# 0            99  caution!: these tracks are not the "original" ...          0  \
# 1           461  just awful: this was possibly the worst book i...          0
# 2           493  no lessons learned: this is one of the most di...          0
# 3           578  squeem: i ordered according to the size chart ...          0
# 4           595  pass: the sizes run really small, it flips up ...          0
# ..          ...                                                ...        ...
# 941       20710  excellent: prompt delivery. correct parts. you...          1
# 942       20711  purchased minn kota mkp 3 prop from amazon.com...          1
# 943       20738  plantronics bluetooth 665 charger: this charge...          1
# 944       20784  video purchase: like the movie so i bought it....          1
# 945       20790  freakin' funny!!!!!!!!!!!!!!!!!!!!!!!!: if you...          1
#
#      num_of_words                                           anon_txt
# 0              22  caution ! : these track are not the " original...  \
# 1              25  just worse : this was possibly the bad book i ...
# 2              23  no lesson speak : this is one of the most pred...
# 3              21  squeem : i order accord to the size chart for ...
# 4              25  pass : the size run really small , it bag up e...
# ..            ...                                                ...
# 941            24  excellent : prompt delivery . correct secret ....
# 942            25  purchase minn kota mkp 3 prop from amazon.com ...
# 943            28  plantronic bluetooth 665 charger : this charge...
# 944            18  video purchase : like the movie so i free it ....
# 945            20  freakin ' funny ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ...
#
#                                       anon_txt_history
# 0    caution!: (these) {track} (are) (not) (the) "o...  \
# 1    (just) [worse] (this) (was) possibly (the) {ba...
# 2    (no) {lesson} {learn} (this) (is) one (of) (th...
# 3    squeem: (i) {order} {accord} (to) (the) size c...
# 4    pass: (the) {size} run really small, (it) {fli...
# ..                                                 ...
# 941  excellent: prompt delivery. correct {part} (yo...
# 942  {purchase} minn kota mkp 3 prop (from) amazon....
# 943  {plantronic} bluetooth 665 charger: (this) cha...
# 944  video purchase: like (the) movie (so) (i) {buy...
# 945  {freakin} funny!!!!!!!!!!!!!!!!!!!!!!!!: (if) ...
#
#                                         force_anon_txt
# 0    * ! : these * are not the " original " version...  \
# 1    just * : this was * the bad book i have ever r...
# 2    no lesson * : this is one of * most * * i have...
# 3    * : i order * to the size * for my * and it wa...
# 4    * : the size * * * , it bag up * * , they * it...
# ..                                                 ...
# 941  excellent : * * . * * . you can not do * with ...
# 942  * * * * 3 * from amazon.com . : the * was * wh...
# 943  * * * * : this * is * for * when you do not ha...
# 944  * purchase : * the * so i * it . * the * in gr...
# 945  * ' * ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ...
#
#      txt_vader_sentiment_pred  anon_txt_vader_sentiment_pred
# 0                      0.0000                        -0.1957  \
# 1                     -0.5574                        -0.2023
# 2                     -0.5563                        -0.0258
# 3                      0.0000                         0.0000
# 4                      0.0000                         0.0000
# ..                        ...                            ...
# 941                    0.8622                         0.9020
# 942                    0.0000                         0.0000
# 943                    0.7841                         0.7841
# 944                    0.8655                         0.9317
# 945                   -0.7946                        -0.6876
#
#      force_anon_txt_vader_sentiment_pred
# 0                                -0.1957
# 1                                -0.5423
# 2                                -0.2960
# 3                                 0.0000
# 4                                 0.0000
# ..                                   ...
# 941                               0.8748
# 942                               0.0000
# 943                               0.4201
# 944                               0.6249
# 945                               0.0000
#
# [946 rows x 10 columns]

# %%
import matplotlib.pyplot as plt

plt.scatter(df_21['txt_vader_sentiment_pred'], df_21['anon_txt_vader_sentiment_pred'])
plt.xlabel('Before annoymization')
plt.ylabel('After annonymization')
plt.title('Sentiment score before and after annonymization');

# %%
plt.scatter(df_21['txt_vader_sentiment_pred'], df_21['force_anon_txt_vader_sentiment_pred'])
plt.xlabel('Before annoymization')
plt.ylabel('After annonymization')
plt.title('Sentiment score before and after annonymization');

# %%
utilization_utils.sentiment_test(df_2, 'txt')
# Out:
# 751    long live mario brothers: i bought this for a ...
# 449    great graphics!: 2006 coast to coast for pc is...
# 624    not used yet: these are spares for the wristro...
# 641    interesting: this is an interesting series for...
# 822    sherry woods: i wanted to read all of sherryl ...
#                              ...
# 385    have not show this one: arrived on time and it...
# 460    good value: i love curve and this is a large b...
# 504    wonderful app: i love reading essence magazine...
# 442    steer clear: steer clear of this blu-ray title...
# 684    i got my moneys worth.: theres nothing about t...
# Name: txt, Length: 756, dtype: object
# 0.8475996376811594

# %%
utilization_utils.sentiment_test(df_2, 'anon_txt')
# Out:
# 688    moonstruck : wonderful movie , can watch it ov...
# 368    lose something in the language : i hope the po...
# 932    well receive : the lanyard and whistle were pu...
# 715    moon understand : this book is very good , int...
# 632    stargate fan : i have been a fan of stargate f...
#                              ...
# 288    just ok : the includes start out work well but...
# 276    no pinyin : i new border and this book does no...
# 584    egyptian technique : this is a wonderful video...
# 671    great series : it can be a little slow at take...
# 815    cult film .... : see this when i was just a ki...
# Name: anon_txt, Length: 756, dtype: object
# 0.7835144927536232

# %% [markdown]
# The fully anonymized text gets he highest accuracy score!

# %%
utilization_utils.sentiment_test(df_2, 'force_anon_txt')
# Out:
# 771    very * : this * is very * , i could not put it...
# 407    * .. : it be * , i just free it for * * . the ...
# 312    * : did not * the * but my money was * refund ...
# 327    * * : i love the * of an * * * . it was great ...
# 237    the order was * : you * too * * which was not ...
#                              ...
# 414    * : do not * this book , it is impossible to *...
# 216    does not work well : the * is * * * * . use th...
# 73     did not * : try to play on two different * - c...
# 930    * * : i * love this movie have not see it go i...
# 530    good * * ! ! : this * * a * * all the * and i ...
# Name: force_anon_txt, Length: 756, dtype: object
# 0.7416213768115942

# %%
print(nlp_utils.stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
len(nlp_utils.stopwords.words('english'))
# Out:
# 179
