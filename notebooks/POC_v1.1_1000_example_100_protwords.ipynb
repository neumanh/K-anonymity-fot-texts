# %% [markdown]
# # POC in a word perspective

# %% [markdown]
# ## Main Algorithm:
#
# 1. Lemmatization
#
# 2. Protect stop words
#
#
# 3. // words (key phrases)
# Do:
# 	Look for similar words (DBSCAN)
# Replace with centroid / one of the members
# Until Embedding distance is too high or utilization is too low.
#
#
# 4. // sentences
# While K-anonymity is not reached:
# Find most similar sentences (Jaccard distance)
# Force them to be similar
#
# 5. Do some utilization test / give some stats…

# %%
# For VSCODE
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ## 0) Upload data

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re

# %% [markdown]
# Import project files

# %%
#import sys
#sys.path.append("utils")
# from utils import models

# %%
from utils import nlp_utils, cluster_utils, utilization_utils, anonym_utils

# %% [markdown]
# Uploading data

# %%
train_file = 'data/df_filtered_1000.csv'
output_name = '1000_example_1000_protected.csv'

# %% [markdown]
# Getting dataframe

# %%
# %%time
# Getting the df
#df = reading_bz_file(train_file)
df = pd.read_csv(train_file)
# Out:
# CPU times: total: 31.2 ms
# Wall time: 18 ms

# %% [markdown]
# ## 1+2) Lemmatizing and protecting stopwords

# %% [markdown]
# Defininig the protected word list

# %%
wide_stop_words = True
if wide_stop_words:
    nlp_utils.add_word_list_to_stop_words('data/1000_most_common_words.txt')
else:
    nlp_utils.stopword_list = nlp_utils.stopwords.words('english')
print('Number of protected words:', len(nlp_utils.stopword_list))
print(nlp_utils.stopword_list[:10])
# Out:
# Number of protected words: 1075
# ['product', 'second', 'pattern', 'an', "wouldn't", 'free', 'on', 'differ', 'does', 'under']

# %% [markdown]
# Defining the word dictionary

# %%
# %%time
word_dict = nlp_utils.create_word_dict(df['txt'])
word_list = cluster_utils.get_word_list_for_clustering(word_dict)
# Out:
# CPU times: total: 21.3 s
# Wall time: 26.8 s

# %%
print('Number of different words:', len(word_dict))
# Out:
# Number of different words: 3281

# %% [markdown]
# ## 3) Word replacement

# %% [markdown]
# ### 3.1) Clustering using DBSCAN

# %% [markdown]
# #### 3.1.1) Using DBSCAN with the default euclidean distance

# %% [markdown]
# Embedding the word list

# %%
embedded_dict = cluster_utils.embed_corpus(word_list)

# %% [markdown]
# Clustering

# %%
# %%time

cluster_dict, dist_dict, labels = cluster_utils.run_clustering(embedded_dict)
# Out:
# eps 1.941760639105046
# CPU times: total: 859 ms
# Wall time: 268 ms

# %%
#for key, val in dist_dict_2.items():
#    print('dist 1:', dist_dict[key], '\tdist 2:', dist_dict_2[key])

# %%
cluster_utils.plot_cluster_size_distribution(cluster_dict)

# %% [markdown]
# Plotting tSNE

# %%
# %%time
cluster_utils.plot_tsne(embedded_dict, labels)
# Out:
# CPU times: total: 52.2 s
# Wall time: 16.6 s

# %% [markdown]
# #### 3.1.2) Using DBSCAN with cosine distance

# %% [markdown]
# Testing DBSCAN with cosine metric

# %%
cluster_dict_cos, dist_dict_cos, labels_cos = cluster_utils.run_clustering(embedded_dict, cosine=True)
# Out:
# eps 0.0821445

# %%
cluster_utils.plot_cluster_size_distribution(cluster_dict_cos)

# %%
# %%time
cluster_utils.plot_tsne(embedded_dict, labels_cos)
# Out:
# CPU times: total: 53.3 s
# Wall time: 17 s

# %% [markdown]
# #### 3.1.3) Using HDBSCAN with UMAP

# %%
cluster_dict_h, dist_dict_h, labels_h = cluster_utils.run_clustering_hdbscan(embedded_dict)

# %%
cluster_utils.plot_cluster_size_distribution(cluster_dict_h)

# %%
cluster_utils.plot_tsne(embedded_dict, labels_h)

# %% [markdown]
# #### 3.1.4) Comapirson

# %%
print('Euclidian distance:\t', len(cluster_dict), 'clusters')
print('Cosine distance:\t', len(cluster_dict_cos), 'clusters')
print('HDBSCAN clustering:\t', len(cluster_dict_h), 'clusters')
# Out:
# Euclidian distance:	 95 clusters
# Cosine distance:	 60 clusters
# HDBSCAN clustering:	 41 clusters

# %% [markdown]
# Plotting Jaccard index histogram

# %%
test_dict = nlp_utils.create_word_dict(['hi, how are you?', 'I love chocolate', 'I love banana', 'he loves cola'])
test_list = cluster_utils.get_word_list_for_clustering(test_dict)
test_list
# Out:
# ['hi', 'banana', 'chocolate', 'cola', 'love']

# %% [markdown]
# Getting distance threshold

# %%
threshold = cluster_utils.define_max_threshold()
threshold
# Out:
# sim_list_best 0.82521856
# sim_list_worst 0.56748897
# 0.3036462366580963

# %% [markdown]
# ### 3.2) Replacing words in documents

# %% [markdown]
# #### 3.2.1) Based on Eucledian distance

# %%
######################### TEMP #######################
#df = df[:30]

# %%
# %%time
df_2, word_dict_2 = nlp_utils.replace_words_in_df(df, cluster_dict, dist_dict, threshold, word_dict)
# Out:
# Starting average Jaccard index: 0.18490998931057948
# Distance threshold: 0.3036462366580963
# distance: 0.34762847 the next cluster is too wide and wont be replaced: ['guy', 'trash', 'unless', 'certainly', 'anyone', 'usually', 'absolutely', 'actually', 'waste', 'barely', 'although', 'yeah', 'mostly', 'crazy', 'shame', 'already', 'wtf', 'finally', 'dick', 'surprised', 'damn', 'normally', 'understand', 'twice', 'handle', 'explain', 'mess', 'forget', 'exactly', 'basically', 'almost', 'anyway', 'anymore', 'fool', 'dirty', 'obviously', 'shut', 'definitely', 'unfortunately', 'aware', 'everytime', 'probably', 'therefore', 'totally', 'suppose', 'however', 'garbage', 'maybe', 'kid', 'fault', 'dude', 'possibly', 'something', 'swear', 'really', 'seriously', 'struggle', 'everything', 'strip', 'otherwise', 'anything', 'hardly', 'hell', 'completely', 'apparently', 'simply', 'nasty', 'yesterday', 'beyond', 'remind', 'impressed']
# distance: 0.16760047 	replacing ['fabulous', 'lovely', 'wonderful'] in beautiful
# distance: 0.228813 	replacing ['application', 'management', 'development', 'client', 'customer'] in services
# distance: 0.32702273 the next cluster is too wide and wont be replaced: ['paxton', 'clark', 'scarlett', 'joe', 'mason', 'elizabeth', 'coltrane', 'johnson', 'boyer', 'john', 'patrick', 'reed', 'carter', 'cornwell', 'paul', 'rebecca', 'elder', 'thomas', 'michael', 'sylvia', 'wayne', 'courtney', 'nightwish', 'peggy', 'phillip', 'clay', 'damme', 'keith', 'quigley', 'mr', 'robert', 'sherry', 'meyer', 'caine', 'chandler', 'karyn', 'lightfoot', 'henry', 'christine', 'browne', 'tarantino', 'miller', 'kelly', 'duncan', 'mrs', 'turner', 'james', 'stevie', 'smith', 'ray', 'gilbert', 'dane', 'wendy', 'kerouac', 'constantine', 'sandler', 'shirley', 'charlie', 'clint', 'frankenstein', 'tony', 'jack', 'parton', 'joseph', 'moby', 'ron']
# distance: 0.19679998 	replacing ['cult', 'rebel', 'feminist'] in slave
# distance: 0.380792 the next cluster is too wide and wont be replaced: ['amazing', 'purchase', 'perfect', 'awesome', 'repetitive', 'package', 'suitable', 'impressive', 'disappointing', 'absolute', 'shipping', 'convenient', 'terrific', 'predictable', 'addition', 'superb', 'outstanding', 'acceptable', 'overall', 'appropriate', 'selection', 'frustrating', 'incredible', 'brilliant', 'unbelievable', 'fantastic']
# distance: 0.1631815 	replacing ['unreadable', 'listenable'] in testable
# distance: 0.12183385 	replacing ['definatly', 'definetely', 'definitly'] in definitley
# distance: 0.21551798 	replacing ['extraordinary', 'powerful', 'ordinary', 'brave'] in minds
# distance: 0.15720426 	replacing ['itit', 'enoy'] in vanie
# distance: 0.20462576 	replacing ['soundtrack', 'comic', 'comedy'] in movie
# distance: 0.14636014 	replacing ['mildly', 'outrageously'] in remarkably
# distance: 0.26845098 	replacing ['twist', 'sock', 'mask', 'tank', 'flip', 'curve', 'pocket', 'boot', 'wrap', 'split', 'flick', 'plug', 'switch', 'chain'] in shoe
# distance: 0.18949798 	replacing ['ultimate', 'fantasy', 'performance'] in epic
# distance: 0.1523853 	replacing ['cgi', 'avid'] in vfx
# distance: 0.16999035 	replacing ['grandson', 'granddaughter', 'grandchild'] in sister-in-law
# distance: 0.19860515 	replacing ['annoying', 'dumb', 'ugly', 'stupid'] in silly
# distance: 0.15607175 	replacing ['purpose', 'temporary'] in requires
# distance: 0.16127132 	replacing ['gossip', 'vampire'] in twilight
# distance: 0.14863709 	replacing ['around', 'outside'] in walk
# distance: 0.24838185 	replacing ['verbose', 'romanticism', 'propriety', 'allegory', 'generalization', 'flimsy', 'vacuous', 'recommendable', 'myopic', 'unimaginative', 'insipid'] in heteronormative
# distance: 0.24527866 	replacing ['entirely', 'somewhat', 'fairly', 'ridiculously', 'extremely', 'incredibly', 'surprisingly', 'amazingly'] in insanely
# distance: 0.16573465 	replacing ['australian', 'british', 'american'] in canadian
# distance: 0.1322829 	replacing ['helpful', 'useful'] in examples
# distance: 0.1567311 	replacing ['shirt', 'sweater', 'jacket'] in hoodie
# distance: 0.12302864 	replacing ['houston', 'brooklyn'] in chicago
# distance: 0.14171132 	replacing ['useless', 'obvious'] in correct
# distance: 0.12433514 	replacing ['vhs', 'bluray'] in borderlands
# distance: 0.08542065 	replacing ['terrible', 'horrible'] in cruel
# distance: 0.12112377 	replacing ['without', 'instead'] in while
# distance: 0.15850355 	replacing ['lore', 'celia'] in irene
# distance: 0.14556077 	replacing ['mandolin', 'backgammon'] in djembe
# distance: 0.08077318 	replacing ['reccomend', 'reccommend'] in somehing
# distance: 0.15025935 	replacing ['education', 'research'] in development
# distance: 0.12893419 	replacing ['episode', 'movie'] in song
# distance: 0.23103514 	replacing ['script', 'theory', 'reference', 'feature', 'graphic'] in book
# distance: 0.18935485 	replacing ['disappoint', 'distract', 'involve'] in rely
# distance: 0.20881668 	replacing ['maker', 'factory', 'dish', 'soap'] in machine
# distance: 0.116455466 	replacing ['cd', 'dvd'] in hd
# distance: 0.2654459 	replacing ['insightful', 'realistic', 'intriguing', 'unrealistic', 'informative'] in compelling
# distance: 0.18595856 	replacing ['battle', 'action', 'talent'] in challenge
# distance: 0.18860011 	replacing ['trinity', 'limerick', 'canterbury', 'winthrop'] in gloucester
# distance: 0.1430272 	replacing ['bother', 'complain'] in argue
# distance: 0.17594948 	replacing ['cage', 'cave', 'temple'] in pond
# distance: 0.14318913 	replacing ['label', 'brand'] in custom
# distance: 0.16594897 	replacing ['princess', 'queen', 'prince'] in king
# distance: 0.17075366 	replacing ['crap', 'awful', 'ridiculous'] in worse
# distance: 0.12575907 	replacing ['daughter', 'husband'] in wife
# distance: 0.12538838 	replacing ['arrival', 'departure'] in returns
# distance: 0.072909445 	replacing ['hahahaha', 'hahaha'] in hahahahaha
# distance: 0.19739814 	replacing ['verison', 'pamphlet', 'discription', 'reveiw'] in puzzler
# distance: 0.19054177 	replacing ['musician', 'songwriter', 'producer'] in singer
# distance: 0.13564105 	replacing ['cheap', 'expensive'] in cheaper
# distance: 0.14797798 	replacing ['purchaser', 'orchestration'] in explorations
# distance: 0.140336 	replacing ['benefit', 'fund'] in funds
# distance: 0.17313468 	replacing ['drawer', 'shelf', 'lamp'] in storage
# distance: 0.15511806 	replacing ['god', 'lord'] in christ
# distance: 0.13167761 	replacing ['camera', 'screen'] in keyboard
# distance: 0.1908299 	replacing ['r', 'u', 'b', 'l'] in f
# distance: 0.19674249 	replacing ['august', 'nov', 'december', 'oct', 'dec'] in june
# distance: 0.14317207 	replacing ['nelly', 'usher'] in wiz
# distance: 0.12665173 	replacing ['playstation', 'nintendo'] in nexus
# distance: 0.15288934 	replacing ['indepth', 'informational'] in writeup
# distance: 0.14701909 	replacing ['illustrate', 'depict'] in simulate
# distance: 0.1932305 	replacing ['kinda', 'creepy', 'weird'] in funny
# distance: 0.25742814 	replacing ['digest', 'instruction', 'setup', 'handbook', 'documentation', 'configuration', 'installation'] in integration
# distance: 0.14012513 	replacing ['india', 'china'] in australia
# distance: 0.14966993 	replacing ['tango', 'bingo'] in sonic
# distance: 0.15601173 	replacing ['price', 'stock'] in discount
# distance: 0.12196259 	replacing ['derivative', 'fodder'] in malfeasance
# distance: 0.18007873 	replacing ['advise', 'clarify', 'refer'] in recognise
# distance: 0.14657459 	replacing ['manual', 'monitor'] in gps
# distance: 0.19572052 	replacing ['comprehensible', 'incomprehensible', 'implausible'] in preposterous
# distance: 0.15901743 	replacing ['pop', 'shake'] in dance
# distance: 0.1412292 	replacing ['edition', 'review'] in project
# distance: 0.20985505 	replacing ['pdf', 'document', 'reader'] in archive
# distance: 0.13114223 	replacing ['amaze', 'nevertheless'] in nonetheless
# distance: 0.13915323 	replacing ['recent', 'previous'] in regarding
# distance: 0.13981587 	replacing ['aspect', 'perspective'] in influence
# distance: 0.16291986 	replacing ['sorry', 'okay'] in nope
# distance: 0.12881479 	replacing ['batman', 'spiderman'] in superman
# distance: 0.15430287 	replacing ['daily', 'production'] in development
# distance: 0.15327854 	replacing ['charle', 'jule'] in shei
# distance: 0.15841702 	replacing ['dryer', 'washer'] in vacuum
# distance: 0.14550528 	replacing ['timely', 'prompt'] in in-depth
# distance: 0.14293985 	replacing ['annoy', 'irritate'] in argue
# distance: 0.15234098 	replacing ['rabbit', 'elephant'] in turtle
# distance: 0.15748943 	replacing ['alpine', 'lodge'] in lighthouse
# distance: 0.15079136 	replacing ['within', 'upon'] in through
# distance: 0.17665899 	replacing ['singer', 'legendary', 'superstar'] in artist
# distance: 0.1422575 	replacing ['writer', 'author'] in editor
# distance: 0.13809226 	replacing ['craftsmanship', 'durability'] in articulation
# distance: 0.15582375 	replacing ['ibook', 'tivo'] in wix
# distance: 0.15431437 	replacing ['none', 'alot'] in lot
# Final average Jaccard index: 0.18971485908802807
# CPU times: total: 17min 9s
# Wall time: 20min 59s

# %%
df_2
# Out:
#      Unnamed: 0                                                txt  sentiment
# 0            99  caution!: these tracks are not the "original" ...          0  \
# 1           461  just awful: this was possibly the worst book i...          0
# 2           493  no lessons learned: this is one of the most di...          0
# 3           578  squeem: i ordered according to the size chart ...          0
# 4           595  pass: the sizes run really small, it flips up ...          0
# ..          ...                                                ...        ...
# 941       20710  excellent: prompt delivery. correct parts. you...          1
# 942       20711  purchased minn kota mkp 3 prop from amazon.com...          1
# 943       20738  plantronics bluetooth 665 charger: this charge...          1
# 944       20784  video purchase: like the movie so i bought it....          1
# 945       20790  freakin' funny!!!!!!!!!!!!!!!!!!!!!!!!: if you...          1
#
#      num_of_words                                           anon_txt
# 0              22  caution ! : these track are not the " original...  \
# 1              25  just worse : this was possibly the bad book i ...
# 2              23  no lesson learn : this is one of the most disa...
# 3              21  squeem : i order accord to the size chart for ...
# 4              25  pass : the size run really small , it shoe up ...
# ..            ...                                                ...
# 941            24  excellent : in-depth delivery . correct part ....
# 942            25  purchase minn kota mkp 3 prop from amazon.com ...
# 943            28  plantronic bluetooth 665 charger : this charge...
# 944            18  video purchase : like the song so i buy it . r...
# 945            20  freakin ' funny ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ...
#
#                                       anon_txt_history  num_replaced
# 0    caution!: (these) {track} (are) (not) (the) ("...             0  \
# 1    (just) [worse] (this) (was) possibly (the) {ba...             1
# 2    (no) {lesson} {learn} (this) (is) (one) (of) (...             1
# 3    squeem: (i) {order} {accord} (to) (the) (size)...             0
# 4    (pass:) (the) {size} (run) really (small,) (it...             0
# ..                                                 ...           ...
# 941  excellent: [in-depth] delivery. (correct) {par...             0
# 942  {purchase} minn kota mkp 3 prop (from) amazon....             0
# 943  {plantronic} bluetooth 665 charger: (this) cha...             0
# 944  video purchase: (like) (the) [song] (so) (i) (...             2
# 945  {freakin} funny!!!!!!!!!!!!!!!!!!!!!!!!: (if) ...             0
#
#      num_lemmatized  num_protected  num_no_change
# 0                 6             12              4
# 1                 3             18              3
# 2                 3             14              5
# 3                 4             13              4
# 4                 4             15              6
# ..              ...            ...            ...
# 941               4             12              8
# 942               3             13              9
# 943               2             16             10
# 944               1             10              5
# 945               4             11              5
#
# [946 rows x 10 columns]

# %% [markdown]
# #### 3.2.2) Based on Cosine distance

# %%
# %%time
df_3, word_dict_3 = nlp_utils.replace_words_in_df(df, cluster_dict_cos, dist_dict_cos, threshold, word_dict)
# Out:
# Starting average Jaccard index: 0.18490998931057948
# Distance threshold: 0.3036462366580963
# distance: 0.3652509 the next cluster is too wide and wont be replaced: ['guy', 'scary', 'today', 'trash', 'hilarious', 'freakin', 'unless', 'certainly', 'annoying', 'anyone', 'usually', 'absolutely', 'actually', 'waste', 'barely', 'without', 'worth', 'although', 'yeah', 'crazy', 'shame', 'everyone', 'crap', 'trust', 'truth', 'already', 'wtf', 'finally', 'dick', 'surprised', 'damn', 'normally', 'easy', 'understand', 'twice', 'handle', 'explain', 'mess', 'forget', 'exactly', 'basically', 'realize', 'dumb', 'someone', 'awful', 'almost', 'kinda', 'yea', 'anyway', 'anymore', 'fool', 'dirty', 'creepy', 'obviously', 'shut', 'definitely', 'unfortunately', 'nearly', 'hate', 'careful', 'probably', 'totally', 'suppose', 'however', 'garbage', 'maybe', 'ugly', 'kid', 'stupid', 'funny', 'worse', 'fault', 'dude', 'possibly', 'something', 'ridiculous', 'swear', 'really', 'seriously', 'struggle', 'everything', 'otherwise', 'serious', 'instead', 'none', 'anything', 'weird', 'hardly', 'hell', 'completely', 'sometimes', 'apparently', 'ass', 'nasty', 'yesterday', 'recognize', 'alot', 'remind', 'impressed']
# distance: 0.31034568 the next cluster is too wide and wont be replaced: ['fabulous', 'amazing', 'perfect', 'awesome', 'impressive', 'lovely', 'beautiful', 'superb', 'wonderful', 'overall', 'incredible', 'brilliant', 'fantastic']
# distance: 0.20188063 	replacing ['pointless', 'nonsense', 'irrelevant'] in confusing
# distance: 0.28013638 	replacing ['application', 'service', 'education', 'information', 'business', 'research', 'daily', 'management', 'development', 'marketing', 'client', 'customer', 'software', 'production'] in services
# distance: 0.15397634 	replacing ['paxton', 'quigley', 'lightfoot'] in menard
# distance: 0.24464536 	replacing ['clark', 'joe', 'mason', 'elizabeth', 'johnson', 'john', 'carter', 'paul', 'rebecca', 'thomas', 'michael', 'phillip', 'keith', 'robert', 'chandler', 'henry', 'miller', 'kelly', 'duncan', 'turner', 'james', 'smith', 'ray', 'gilbert', 'tony', 'jack', 'joseph'] in scott
# distance: 0.12183385 	replacing ['definatly', 'definetely', 'definitly'] in definitley
# distance: 0.13647193 	replacing ['extraordinary', 'ordinary'] in powerful
# distance: 0.18465962 	replacing ['purchase', 'package', 'shipping'] in discount
# distance: 0.14636014 	replacing ['mildly', 'outrageously'] in remarkably
# distance: 0.22681446 	replacing ['ultimate', 'series', 'fantasy', 'performance'] in epic
# distance: 0.12681131 	replacing ['grandson', 'granddaughter'] in grandfather
# distance: 0.25404572 	replacing ['bag', 'shirt', 'tank', 'flip', 'sweater', 'pocket', 'jacket'] in shoes
# distance: 0.23614866 	replacing ['around', 'across', 'outside', 'inside', 'away'] in into
# distance: 0.15368041 	replacing ['math', 'essay'] in physics
# distance: 0.2624211 	replacing ['entirely', 'wonderfully', 'somewhat', 'fairly', 'ridiculously', 'extremely', 'incredibly', 'surprisingly', 'amazingly'] in insanely
# distance: 0.16573465 	replacing ['australian', 'british', 'american'] in canadian
# distance: 0.1322829 	replacing ['helpful', 'useful'] in examples
# distance: 0.12302864 	replacing ['houston', 'brooklyn'] in chicago
# distance: 0.08542065 	replacing ['terrible', 'horrible'] in cruel
# distance: 0.08077318 	replacing ['reccomend', 'reccommend'] in somehing
# distance: 0.12893419 	replacing ['episode', 'movie'] in song
# distance: 0.124564126 	replacing ['script', 'reference'] in feature
# distance: 0.116455466 	replacing ['cd', 'dvd'] in hd
# distance: 0.23287658 	replacing ['c', 'r', 'u', 'b', 'l'] in m
# distance: 0.19348662 	replacing ['insightful', 'intriguing', 'informative'] in thought-provoking
# distance: 0.20370728 	replacing ['bother', 'quit', 'complain'] in wont
# distance: 0.14318913 	replacing ['label', 'brand'] in custom
# distance: 0.16594897 	replacing ['princess', 'queen', 'prince'] in king
# distance: 0.18222214 	replacing ['daughter', 'husband', 'nephew'] in wife
# distance: 0.1668697 	replacing ['disappointing', 'predictable', 'frustrating'] in upsetting
# distance: 0.072909445 	replacing ['hahahaha', 'hahaha'] in hahahahaha
# distance: 0.14742202 	replacing ['musician', 'songwriter'] in producer
# distance: 0.13564105 	replacing ['cheap', 'expensive'] in cheaper
# distance: 0.21718602 	replacing ['benefit', 'fund', 'opportunity'] in ensure
# distance: 0.12257018 	replacing ['drawer', 'shelf'] in storage
# distance: 0.1137208 	replacing ['sylvia', 'peggy'] in doris
# distance: 0.15511806 	replacing ['god', 'lord'] in christ
# distance: 0.13158196 	replacing ['wayne', 'stevie'] in ross
# distance: 0.13167761 	replacing ['camera', 'screen'] in keyboard
# distance: 0.13584258 	replacing ['realistic', 'unrealistic'] in insignificant
# distance: 0.19674249 	replacing ['august', 'nov', 'december', 'oct', 'dec'] in june
# distance: 0.14012513 	replacing ['india', 'china'] in australia
# distance: 0.15601173 	replacing ['price', 'stock'] in discount
# distance: 0.20984225 	replacing ['curve', 'plug', 'switch', 'charger'] in lock
# distance: 0.15424156 	replacing ['blessing', 'prayer'] in praise
# distance: 0.13915323 	replacing ['recent', 'previous'] in regarding
# distance: 0.13981587 	replacing ['aspect', 'perspective'] in influence
# distance: 0.16291986 	replacing ['sorry', 'okay'] in nope
# distance: 0.15841702 	replacing ['dryer', 'washer'] in vacuum
# distance: 0.16021785 	replacing ['uncomfortable', 'comfortable'] in quiet
# distance: 0.14293985 	replacing ['annoy', 'irritate'] in argue
# distance: 0.13060571 	replacing ['acceptable', 'appropriate'] in purely
# distance: 0.1431529 	replacing ['dish', 'soap'] in bubble
# distance: 0.15079136 	replacing ['within', 'upon'] in through
# distance: 0.15213303 	replacing ['singer', 'superstar'] in artist
# distance: 0.1422575 	replacing ['writer', 'author'] in editor
# distance: 0.12640539 	replacing ['limerick', 'winthrop'] in carleton
# distance: 0.1274725 	replacing ['unimaginative', 'insipid'] in antagonistic
# Final average Jaccard index: 0.18942729640404882
# CPU times: total: 10min 27s
# Wall time: 11min 36s

# %%
df_3
# Out:
#      Unnamed: 0                                                txt  sentiment
# 0            99  caution!: these tracks are not the "original" ...          0  \
# 1           461  just awful: this was possibly the worst book i...          0
# 2           493  no lessons learned: this is one of the most di...          0
# 3           578  squeem: i ordered according to the size chart ...          0
# 4           595  pass: the sizes run really small, it flips up ...          0
# ..          ...                                                ...        ...
# 941       20710  excellent: prompt delivery. correct parts. you...          1
# 942       20711  purchased minn kota mkp 3 prop from amazon.com...          1
# 943       20738  plantronics bluetooth 665 charger: this charge...          1
# 944       20784  video purchase: like the movie so i bought it....          1
# 945       20790  freakin' funny!!!!!!!!!!!!!!!!!!!!!!!!: if you...          1
#
#      num_of_words                                           anon_txt
# 0              22  caution ! : these track are not the " original...  \
# 1              25  just awful : this was possibly the bad book i ...
# 2              23  no lesson learn : this is one of the most upse...
# 3              21  squeem : i order accord to the size chart for ...
# 4              25  pass : the size run really small , it shoes up...
# ..            ...                                                ...
# 941            24  excellent : prompt delivery . correct part . y...
# 942            25  discount minn kota mkp 3 prop from amazon.com ...
# 943            28  plantronic bluetooth 665 lock : this lock is g...
# 944            18  video discount : like the song so i buy it . r...
# 945            20  freakin ' funny ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ...
#
#                                       anon_txt_history  num_replaced
# 0    caution!: (these) {track} (are) (not) (the) ("...             1  \
# 1    (just) [worse] (this) (was) possibly (the) {ba...             1
# 2    (no) {lesson} {learn} (this) (is) (one) (of) (...             2
# 3    squeem: (i) {order} {accord} (to) (the) (size)...             0
# 4    (pass:) (the) {size} (run) really (small,) (it...             0
# ..                                                 ...           ...
# 941  excellent: [in-depth] delivery. (correct) {par...             1
# 942  {purchase} minn kota mkp 3 prop (from) amazon....             0
# 943  {plantronic} bluetooth 665 [lock] (this) [lock...             2
# 944  video [discount] (like) (the) [song] (so) (i) ...             3
# 945  {freakin} funny!!!!!!!!!!!!!!!!!!!!!!!!: (if) ...             0
#
#      num_lemmatized  num_protected  num_no_change
# 0                 6             12              3
# 1                 3             18              3
# 2                 3             14              4
# 3                 4             13              4
# 4                 4             15              6
# ..              ...            ...            ...
# 941               4             12              7
# 942               3             13              9
# 943               2             16              8
# 944               1             10              4
# 945               4             11              5
#
# [946 rows x 10 columns]

# %% [markdown]
# #### 3.2.3) Based on HDBSCAN clustering

# %%
# %%time
df_4, word_dict_4 = nlp_utils.replace_words_in_df(df, cluster_dict_h, dist_dict_h, threshold, word_dict)
# Out:
# Starting average Jaccard index: 0.18490998931057948
# Distance threshold: 0.3036462366580963
# distance: 0.36113602 the next cluster is too wide and wont be replaced: ['guy', 'scary', 'huh', 'annoying', 'yeah', 'crazy', 'wtf', 'suck', 'dick', 'damn', 'meh', 'salty', 'dumb', 'bet', 'chill', 'dirty', 'creepy', 'shut', 'sorry', 'ugly', 'kid', 'stupid', 'wow', 'funny', 'dude', 'swear', 'weird', 'hell', 'soo', 'ass', 'nasty', 'wat']
# distance: 0.34586146 the next cluster is too wide and wont be replaced: ['imaginative', 'reliable', 'helpful', 'fascinating', 'realistic', 'intriguing', 'inexpensive', 'reasonable', 'energetic', 'profound', 'upbeat', 'informative']
# distance: 0.42634168 the next cluster is too wide and wont be replaced: ['shower', 'pet', 'copper', 'bag', 'fireplace', 'junk', 'mug', 'converse', 'holder', 'purple', 'shirt', 'backpack', 'flavor', 'penny', 'cereal', 'delicious', 'sock', 'diet', 'bottle', 'grab', 'pajama', 'mask', 'tank', 'microwave', 'drawer', 'grip', 'sandal', 'flip', 'shelf', 'strap', 'rice', 'brush', 'polyester', 'candy', 'tea', 'spray', 'bug', 'sweater', 'cheesy', 'lamp', 'magnum', 'curve', 'giant', 'necklace', 'bra', 'stud', 'pocket', 'airplane', 'bean', 'purse', 'helmet', 'taste', 'boot', 'puppy', 'dryer', 'garbage', 'wrap', 'yum', 'washer', 'split', 'stamp', 'oreo', 'dish', 'cardboard', 'rabbit', 'pack', 'knife', 'soap', 'scratch', 'freezer', 'chocolate', 'plastic', 'coin', 'fabric', 'timer', 'vibrator', 'recipe', 'coffee', 'compact', 'jacket', 'bead', 'frame', 'bike', 'chain', 'cake', 'lightweight']
# distance: 0.35446796 the next cluster is too wide and wont be replaced: ['saddest', 'thrill', 'encounter', 'savior', 'innocence', 'peaceful', 'mercy', 'curiosity', 'eternal', 'magical', 'wicked', 'brave', 'fallen']
# distance: 0.41145137 the next cluster is too wide and wont be replaced: ['leaky', 'uranium', 'girdle', 'seam', 'wart', 'drippy', 'undershirt', 'toenail', 'crumpet', 'splint', 'scratcher', 'ehhh', 'thickest', 'thyroid', 'playtex', 'noose', 'earing', 'lanyard', 'handkerchief', 'spanx', 'firearm', 'stun', 'rotate', 'opend']
# distance: 0.3797049 the next cluster is too wide and wont be replaced: ['grateful', 'confuse', 'certainly', 'disturb', 'usually', 'although', 'disappoint', 'happily', 'mostly', 'stumble', 'thou', 'easily', 'expose', 'frankly', 'distract', 'hesitate', 'insult', 'likely', 'personally', 'normally', 'beware', 'involve', 'interested', 'quicker', 'advise', 'accomplish', 'fully', 'entertain', 'depress', 'amaze', 'manage', 'spiritually', 'unfortunately', 'aware', 'sincerely', 'therefore', 'badly', 'whatsoever', 'however', 'shy', 'annoy', 'acceptable', 'respond', 'properly', 'intend', 'possibly', 'truly', 'pronounce', 'otherwise', 'unable', 'continuously', 'warn', 'frequently', 'hardly', 'pity', 'clarify', 'simply', 'comfortable', 'refer', 'irritate', 'beyond', 'recognize', 'avoid', 'become']
# distance: 0.42158422 the next cluster is too wide and wont be replaced: ['pointless', 'silence', 'mental', 'purpose', 'amount', 'disappointment', 'absurd', 'important', 'moral', 'painful', 'concern', 'ego', 'antisocial', 'effort', 'irrelevant', 'emotion', 'negative', 'false', 'resolve', 'intense', 'meaning', 'familiar', 'humor', 'lack', 'superficial', 'friendly', 'define', 'excitement', 'situation', 'frustrating', 'opinion', 'impossible', 'temporary', 'apology']
# distance: 0.36385062 the next cluster is too wide and wont be replaced: ['trash', 'twist', 'whistle', 'cop', 'drag', 'strand', 'hook', 'toe', 'collar', 'flick', 'strip', 'transformer', 'spin', 'shot', 'tent']
# distance: 0.34973547 the next cluster is too wide and wont be replaced: ['application', 'exchange', 'service', 'education', 'information', 'agency', 'credit', 'medical', 'target', 'fund', 'business', 'research', 'promote', 'technical', 'daily', 'access', 'address', 'program', 'management', 'development', 'marketing', 'retail', 'client', 'apply', 'customer', 'bill']
# distance: 0.34029785 the next cluster is too wide and wont be replaced: ['jefferson', 'albert', 'clark', 'quentin', 'joe', 'mason', 'elizabeth', 'saint', 'johnson', 'john', 'patrick', 'reed', 'shin', 'carter', 'paul', 'rebecca', 'thomas', 'michael', 'wayne', 'courtney', 'nelly', 'phillip', 'christian', 'keith', 'harry', 'mr', 'cher', 'robert', 'mario', 'chandler', 'romero', 'clifford', 'henry', 'christine', 'miller', 'julia', 'abraham', 'lisa', 'gabriel', 'kelly', 'duncan', 'mrs', 'julie', 'turner', 'james', 'ann', 'jordan', 'stevie', 'smith', 'duke', 'ray', 'gilbert', 'rip', 'adam', 'wendy', 'perry', 'charlie', 'usher', 'nick', 'clint', 'prince', 'tony', 'jack', 'sung', 'joseph', 'ron']
# distance: 0.43294665 the next cluster is too wide and wont be replaced: ['goodi', 'workmanship', 'unreadable', 'verbose', 'uptodate', 'overrate', 'cheep', 'critism', 'discontinue', 'depiction', 'unsupported', 'autobot', 'distasteful', 'talente', 'inflate', 'eloquence', 'synch', 'amazoncom', 'foreshadow', 'transcribe', 'listenable', 'paraphrase', 'comprehensible', 'generalization', 'suspenseful', 'bothersome', 'disapointment', 'deceptive', 'forgettable', 'capitalistic', 'actionmovie', 'higly', 'flimsy', 'vacuous', 'watchig', 'recommendable', 'disparage', 'myopic', 'nonexistant', 'incomprehensible', 'induce', 'grat', 'waster', 'annotate', 'trite', 'producti', 'aweful', 'overprice', 'craftsmanship', 'durability', 'trought', 'unimaginative', 'insipid', 'deliverd', 'flavorless', 'implausible', 'fabu', 'recomend']
# distance: 0.3910363 the next cluster is too wide and wont be replaced: ['apache', 'cavalier', 'rattle', 'belkin', 'emporio', 'decode', 'psi', 'bluegrass', 'supersonic', 'bose', 'nomad', 'dorman', 'stargate', 'cq', 'crook', 'juvenile', 'grillz', 'tuscan']
# distance: 0.37031755 the next cluster is too wide and wont be replaced: ['refresh', 'seller', 'rental', 'delivery', 'package', 'description', 'bulk', 'detail', 'shipping', 'price', 'stock', 'document', 'retailer', 'gift']
# distance: 0.41482195 the next cluster is too wide and wont be replaced: ['hitec', 'aal', 'compaire', 'itit', 'morrillo', 'congrat', 'anake', 'minn', 'rut', 'ime', 'iii', 'mkp', 'purgatorio', 'agan', 'muni', 'caan', 'dud', 'gad', 'pamer', 'waas', 'tbone', 'wep', 'charle', 'doone', 'tomcat', 'mog', 'addy', 'thia', 'soso', 'zelia', 'mule', 'zuk', 'scarpetta', 'enoy', 'wase', 'iti', 'zzzzzz', 'jule']
# distance: 0.36819023 the next cluster is too wide and wont be replaced: ['unless', 'entire', 'anyone', 'around', 'whoever', 'actually', 'without', 'worth', 'bother', 'across', 'shame', 'everyone', 'trust', 'truth', 'already', 'outside', 'finally', 'another', 'god', 'thru', 'belong', 'understand', 'twice', 'explain', 'forget', 'exactly', 'basically', 'quit', 'realize', 'someone', 'almost', 'awhile', 'regret', 'obviously', 'complain', 'definitely', 'apart', 'nearly', 'everytime', 'nap', 'probably', 'suppose', 'promise', 'worse', 'fault', 'eaten', 'inside', 'something', 'plenty', 'nowhere', 'really', 'everything', 'instead', 'none', 'anything', 'away', 'sometimes', 'apparently', 'til', 'yesterday', 'lose', 'hide', 'treat', 'remind', 'appreciate']
# distance: 0.40627858 the next cluster is too wide and wont be replaced: ['cable', 'collection', 'vhs', 'cassette', 'fashion', 'replacement', 'router', 'bluray', 'camera', 'screen', 'playstation', 'battery', 'scanner', 'nook', 'kit', 'manual', 'disk', 'vcr', 'pdf', 'bluetooth', 'opera', 'headset', 'fps', 'vehicle', 'laptop', 'adapter', 'deluxe', 'pad', 'monitor', 'model', 'item', 'kindle', 'multi', 'dvr', 'computer', 'scan', 'canon', 'tablet', 'ebook', 'desktop', 'xl', 'unrated', 'printer', 'nintendo', 'volume', 'digital', 'disc', 'custom', 'amplifier', 'charger']
# distance: 0.34246695 the next cluster is too wide and wont be replaced: ['paxton', 'morillo', 'coltrane', 'boyer', 'garwood', 'cornwell', 'carnegie', 'feehan', 'sherryl', 'jonestown', 'bozo', 'quigley', 'gerson', 'caine', 'asimov', 'bunyan', 'lightfoot', 'browne', 'myer', 'wiley', 'huxley', 'kerouac', 'constantine', 'devlin', 'rueben', 'caspian', "o'connor", 'langston', 'phelan', 'verne', 'ryu']
# distance: 0.3992782 the next cluster is too wide and wont be replaced: ['valuable', 'manner', 'powerful', 'goodness', 'discipline', 'happiness', 'desire', 'aspect', 'inspirational', 'creativity', 'upon', 'determination', 'behaviour', 'imagination', 'prayer', 'lord']
# distance: 0.42863345 the next cluster is too wide and wont be replaced: ['pl', 'beach', 'australian', 'catholic', 'invasion', 'breeze', 'uk', 'sf', 'american', 'prime', 'iraqi', 'india', 'border', 'china', 'cave', 'amish', 'rebel', 'america', 'lane', 'former', 'frost', 'elementary', 'civil', 'local', 'portuguese', 'temple', 'german', 'occupy', 'egyptian', 'western', 'sole', 'shia', 'mexico', 'aviation']
# distance: 0.3265136 the next cluster is too wide and wont be replaced: ['amazing', 'perfect', 'awesome', 'nice', 'birthday', 'sweet', 'lovely', 'beautiful', 'wonderful', 'christmas', 'favorite', 'enjoy', 'adorable']
# distance: 0.3550457 the next cluster is too wide and wont be replaced: ['phd', 'outline', 'library', 'textbook', 'bookstore', 'instructor', 'reference', 'literature', 'translation', 'bilingual', 'beginner', 'digest', 'practitioner', 'handbook', 'documentation', 'reviewer', 'intermediate', 'configuration', 'installation', 'programming']
# distance: 0.40273625 the next cluster is too wide and wont be replaced: ['e', 'p', 'k', 'c', 'r', 'u', 'x', 'b', "'", 'l', 'g', 'j', 'ya', 'w', 'da']
# distance: 0.3994968 the next cluster is too wide and wont be replaced: ['damage', 'constitution', 'percent', 'majority', 'criminal', 'lower', 'foreign', 'disaster', 'opportunity', 'society', 'violence', 'effective', 'improvement', 'growth', 'religion', 'intelligence', 'political', 'suicide', 'despite', 'risk', 'religious']
# distance: 0.40967438 the next cluster is too wide and wont be replaced: ['soundtrack', 'ultimate', 'gossip', 'version', 'stage', 'romance', 'novel', 'channel', 'episode', 'series', 'musical', 'theory', 'golden', 'vocal', 'cd', 'battle', 'fantasy', 'tune', 'anatomy', 'wwe', 'comic', 'classic', 'choice', 'poster', 'ballet', 'theater', 'guitar', 'scene', 'lyric', 'concert', 'disney', 'adventure', 'album', 'madden', 'netflix', 'cast', 'suspense', 'cup', 'baseball', 'songwriter', 'dragon', 'castle', 'pop', 'video', 'pic', 'recording', 'survival', 'olympic', 'spongebob', 'documentary', 'sequel', 'batman', 'acoustic', 'vampire', 'halloween', 'epic', 'quiz', 'spiderman', 'magic', 'producer', 'serial', 'performance', 'cartoon', 'style', 'zombie', 'writer', 'drama', 'bash', 'legendary', 'comedy', 'bingo', 'chemistry', 'footage', 'tv', 'horror', 'movie', 'porno', 'superstar', 'official', 'funk', 'film', 'clip']
# distance: 0.36170405 the next cluster is too wide and wont be replaced: ['weak', 'mess', 'alone', 'fool', 'sad', 'freak', 'maybe', 'blah', 'forever', 'mood', 'serious', 'messy', 'nothin', 'sum']
# distance: 0.36634314 the next cluster is too wide and wont be replaced: ['math', 'teacher', 'grammar', 'topic', 'essay', 'revise', 'teaching', 'english', 'algebra', 'lesson', 'grade', 'professor']
# distance: 0.32337114 the next cluster is too wide and wont be replaced: ['entirely', 'immensely', 'wonderfully', 'somewhat', 'socially', 'horribly', 'fairly', 'highly', 'ridiculously', 'extremely', 'utterly', 'slightly', 'poorly', 'incredibly', 'surprisingly', 'thoroughly', 'amazingly']
# distance: 0.409218 the next cluster is too wide and wont be replaced: ['execpt', 'dujour', 'abridge', 'baggin', 'softcover', 'verison', 'purchaser', 'romanticism', 'neopet', 'indepth', 'pamphlet', 'allegory', 'trekkie', 'almanac', 'defect', 'backorder', 'paranoiac', 'consort', 'triology', 'fodder', 'informational', 'discription', 'purport', 'writeup', 'goer', 'moonstruck', 'orchestration', 'reveiw', 'worshipper', 'breakroom', 'tivo', 'remastere']
# distance: 0.32031262 the next cluster is too wide and wont be replaced: ['japan', 'st', 'return', 'august', 'release', 'nov', 'december', 'announce', 'oct', 'dec', 'th']
# distance: 0.38688737 the next cluster is too wide and wont be replaced: ['thumb', 'remover', 'gently', 'cheek', 'blend', 'tear', 'tongue', 'knee', 'tooth', 'tight', 'facial', 'loose', 'muscle', 'fold']
# distance: 0.43832296 the next cluster is too wide and wont be replaced: ['phone', 'daughter', 'mention', 'boyfriend', 'nephew']
# distance: 0.49434444 the next cluster is too wide and wont be replaced: ['tenia', 'mono', 'dale', 'primer', 'vista', 'ti', 'al', 'pos', 'pan', 'uf', 'gane', 'va', 'dice', 'senti', 'vale']
# distance: 0.43701157 the next cluster is too wide and wont be replaced: ['additional', 'action', 'requirement', 'extend', 'reception', 'generation', 'hike', 'trick', 'unique', 'gain', 'protection', 'prompt', 'rate', 'leader', 'secret']
# distance: 0.35577926 the next cluster is too wide and wont be replaced: ['preserve', 'fulfill', 'explore', 'establish', 'organize', 'heal']
# distance: 0.27975798 	replacing ['attach', 'grasp', 'absorb', 'arise', 'convey', 'steer'] in distinguish
# distance: 0.43874064 the next cluster is too wide and wont be replaced: ['inaug', 'grandchild', 'cataclysm', 'mote', 'fasion', 'ibook']
# distance: 0.2837415 	replacing ['concept', 'booklet', 'setup', 'graphic', 'professional'] in feature
# distance: 0.27862838 	replacing ['bilbo', 'lorna', 'sandler', 'mosby', 'bradbury', 'frankenstein'] in morrissey
# distance: 0.36086962 the next cluster is too wide and wont be replaced: ['shock', 'memory', 'functional']
# distance: 0.2696791 	replacing ['timely', 'indication', 'inaccurate'] in factual
# Final average Jaccard index: 0.18512549851621102
# CPU times: total: 6min 50s
# Wall time: 7min 14s

# %%
df_4
# Out:
#      Unnamed: 0                                                txt  sentiment
# 0            99  caution!: these tracks are not the "original" ...          0  \
# 1           461  just awful: this was possibly the worst book i...          0
# 2           493  no lessons learned: this is one of the most di...          0
# 3           578  squeem: i ordered according to the size chart ...          0
# 4           595  pass: the sizes run really small, it flips up ...          0
# ..          ...                                                ...        ...
# 941       20710  excellent: prompt delivery. correct parts. you...          1
# 942       20711  purchased minn kota mkp 3 prop from amazon.com...          1
# 943       20738  plantronics bluetooth 665 charger: this charge...          1
# 944       20784  video purchase: like the movie so i bought it....          1
# 945       20790  freakin' funny!!!!!!!!!!!!!!!!!!!!!!!!: if you...          1
#
#      num_of_words                                           anon_txt
# 0              22  caution ! : these track are not the " original...  \
# 1              25  just awful : this was possibly the bad book i ...
# 2              23  no lesson learn : this is one of the most disa...
# 3              21  squeem : i order accord to the size chart for ...
# 4              25  pass : the size run really small , it flip up ...
# ..            ...                                                ...
# 941            24  excellent : prompt delivery . correct part . y...
# 942            25  purchase minn kota mkp 3 prop from amazon.com ...
# 943            28  plantronic bluetooth 665 charger : this charge...
# 944            18  video purchase : like the movie so i buy it . ...
# 945            20  freakin ' funny ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ...
#
#                                       anon_txt_history  num_replaced
# 0    caution!: (these) {track} (are) (not) (the) ("...             1  \
# 1    (just) [worse] (this) (was) possibly (the) {ba...             1
# 2    (no) {lesson} {learn} (this) (is) (one) (of) (...             2
# 3    squeem: (i) {order} {accord} (to) (the) (size)...             0
# 4    (pass:) (the) {size} (run) really (small,) (it...             0
# ..                                                 ...           ...
# 941  excellent: [in-depth] delivery. (correct) {par...             1
# 942  {purchase} minn kota mkp 3 prop (from) amazon....             0
# 943  {plantronic} bluetooth 665 [lock] (this) [lock...             2
# 944  video [discount] (like) (the) [song] (so) (i) ...             3
# 945  {freakin} funny!!!!!!!!!!!!!!!!!!!!!!!!: (if) ...             0
#
#      num_lemmatized  num_protected  num_no_change
# 0                 6             12              3
# 1                 3             18              3
# 2                 3             14              4
# 3                 4             13              4
# 4                 4             15              6
# ..              ...            ...            ...
# 941               4             12              7
# 942               3             13              9
# 943               2             16              8
# 944               1             10              4
# 945               4             11              5
#
# [946 rows x 10 columns]

# %% [markdown]
# Looking at the histogram again

# %%
# %%time
nlp_utils.plot_jaccard_hist(df_2, column='txt')
# Out:
# CPU times: total: 6 s
# Wall time: 8.11 s

# %%
# %%time
nlp_utils.plot_jaccard_hist(df_2, 'anon_txt')
# Out:
# CPU times: total: 6.92 s
# Wall time: 10 s

# %% [markdown]
# For eucledian distance

# %%
protected, lemma, replaced, all_words = nlp_utils.get_stat(word_dict_2)
print(f'Protected: {protected}\tLemmatized: {lemma}\t Replaced: {replaced}\t All: {all_words}')
# Out:
# Protected: 678	Lemmatized: 928	 Replaced: 307	 All: 3307

# %%
y = np.array([protected, lemma, replaced, (all_words - protected - lemma - replaced)])
mylabels = ['protected', 'lemmatized', 'replaced', 'no change']

plt.pie(y, labels = mylabels)
plt.title('Words in voccabulary')
plt.show()

# %%
y = np.array([df_2['num_protected'].sum(), df_2['num_lemmatized'].sum(), df_2['num_replaced'].sum(), df_2['num_no_change'].sum()])
mylabels = ['protected', 'lemmatized', 'replaced', 'no change']

plt.pie(y, labels = mylabels)
plt.title('Words in dataset')
plt.show()

# %% [markdown]
# ## 4) Force anonymity

# %% [markdown]
# ### Get anonymity degree

# %% [markdown]
# Before replacement

# %%
curr_k, non_anon_indexes = anonym_utils.get_anonym_degree(docs=df_2['txt'])
print('Current k:', curr_k, '\tnumber of un-anonym. documents:', len(non_anon_indexes), '\tnumber of all documents:', len(df_2['txt']))
# Out:
# Current k: 1 	number of un-anonym. documents: 944 	number of all documents: 946

# %% [markdown]
# After replacement

# %%
curr_k, non_anon_indexes = anonym_utils.get_anonym_degree(docs=df_2['anon_txt'])
print('Current k:', curr_k, '\tnumber of un-anonym. documents:', len(non_anon_indexes), '\tnumber of all documents:', len(df_2['anon_txt']))
# Out:
# Current k: 1 	number of un-anonym. documents: 944 	number of all documents: 946

# %% [markdown]
# ### Steps:
# 1. Finding k nearest neighbors using approximate nearest neighbors
# 2. Finding the different words between the neighbors
# 2. Replacing the different words with *

# %%
anonym_utils.delete_uncommon_words(['I love choco', 'I love banana'])
# Out:
# ['I love *', 'I love *']

# %%
anonym_utils.force_anonym_using_annoy(['I love choco', 'I love banana', 'lalala'], k=2)
# Out:
# Start: get_anonym_degree: 1
# similar_doc_ind [0, 1]
# Breaking after moving over 2 of all 3 indexes.
# unused_indexes: [2]
# End: get_anonym_degree: 1
# ['I love *', 'I love *', '*']

# %%
force_anon_txt_annoy = anonym_utils.force_anonym_using_annoy(df_2['anon_txt'], k=2)
anonym_utils.get_anonym_degree(force_anon_txt_annoy)
# Out:
# Start: get_anonym_degree: 1
# similar_doc_ind [0, 298]
# similar_doc_ind [1, 265]
# similar_doc_ind [2, 754]
# similar_doc_ind [3, 246]
# similar_doc_ind [4, 534]
# similar_doc_ind [5, 6]
# similar_doc_ind [7, 424]
# similar_doc_ind [8, 117]
# similar_doc_ind [9, 540]
# similar_doc_ind [10, 12]
# similar_doc_ind [11, 369]
# similar_doc_ind [13, 384]
# similar_doc_ind [14, 920]
# similar_doc_ind [15, 314]
# similar_doc_ind [16, 231]
# similar_doc_ind [17, 907]
# similar_doc_ind [18, 653]
# similar_doc_ind [19, 370]
# similar_doc_ind [20, 213]
# similar_doc_ind [21, 355]
# similar_doc_ind [22, 685]
# similar_doc_ind [23, 166]
# similar_doc_ind [24, 425]
# similar_doc_ind [25, 372]
# similar_doc_ind [26, 140]
# similar_doc_ind [27, 403]
# similar_doc_ind [28, 143]
# similar_doc_ind [29, 77]
# similar_doc_ind [30, 530]
# similar_doc_ind [31, 159]
# similar_doc_ind [32, 255]
# similar_doc_ind [33, 287]
# similar_doc_ind [34, 48]
# similar_doc_ind [35, 40]
# similar_doc_ind [36, 615]
# similar_doc_ind [37, 590]
# similar_doc_ind [38, 501]
# similar_doc_ind [39, 436]
# similar_doc_ind [41, 809]
# similar_doc_ind [42, 236]
# similar_doc_ind [43, 84]
# similar_doc_ind [44, 161]
# similar_doc_ind [45, 388]
# similar_doc_ind [46, 138]
# similar_doc_ind [47, 728]
# similar_doc_ind [49, 488]
# similar_doc_ind [50, 248]
# similar_doc_ind [51, 94]
# similar_doc_ind [52, 354]
# similar_doc_ind [53, 413]
# similar_doc_ind [54, 154]
# similar_doc_ind [55, 801]
# similar_doc_ind [56, 571]
# similar_doc_ind [57, 151]
# similar_doc_ind [58, 539]
# similar_doc_ind [59, 776]
# similar_doc_ind [60, 667]
# similar_doc_ind [61, 898]
# similar_doc_ind [62, 498]
# similar_doc_ind [63, 831]
# similar_doc_ind [64, 924]
# similar_doc_ind [65, 284]
# similar_doc_ind [66, 646]
# similar_doc_ind [67, 192]
# similar_doc_ind [68, 219]
# similar_doc_ind [69, 194]
# similar_doc_ind [70, 303]
# similar_doc_ind [71, 190]
# similar_doc_ind [72, 329]
# similar_doc_ind [73, 243]
# similar_doc_ind [74, 301]
# similar_doc_ind [75, 439]
# similar_doc_ind [76, 203]
# similar_doc_ind [78, 86]
# similar_doc_ind [79, 637]
# similar_doc_ind [80, 179]
# similar_doc_ind [81, 83]
# similar_doc_ind [82, 855]
# similar_doc_ind [85, 227]
# similar_doc_ind [87, 515]
# similar_doc_ind [88, 576]
# similar_doc_ind [89, 268]
# similar_doc_ind [90, 98]
# similar_doc_ind [91, 429]
# similar_doc_ind [92, 244]
# similar_doc_ind [93, 604]
# similar_doc_ind [95, 802]
# similar_doc_ind [96, 400]
# similar_doc_ind [97, 579]
# similar_doc_ind [99, 558]
# similar_doc_ind [100, 252]
# similar_doc_ind [101, 241]
# similar_doc_ind [102, 311]
# similar_doc_ind [103, 111]
# similar_doc_ind [104, 198]
# similar_doc_ind [105, 269]
# similar_doc_ind [106, 755]
# similar_doc_ind [107, 266]
# similar_doc_ind [108, 395]
# similar_doc_ind [109, 148]
# similar_doc_ind [110, 165]
# similar_doc_ind [112, 525]
# similar_doc_ind [113, 839]
# similar_doc_ind [114, 121]
# similar_doc_ind [115, 224]
# similar_doc_ind [116, 184]
# similar_doc_ind [118, 250]
# similar_doc_ind [119, 318]
# similar_doc_ind [120, 136]
# similar_doc_ind [122, 137]
# similar_doc_ind [123, 176]
# similar_doc_ind [124, 393]
# similar_doc_ind [125, 288]
# similar_doc_ind [126, 703]
# similar_doc_ind [127, 302]
# similar_doc_ind [128, 193]
# similar_doc_ind [129, 633]
# similar_doc_ind [130, 648]
# similar_doc_ind [131, 132]
# similar_doc_ind [133, 134]
# similar_doc_ind [135, 700]
# similar_doc_ind [139, 624]
# similar_doc_ind [141, 274]
# similar_doc_ind [142, 191]
# similar_doc_ind [144, 174]
# similar_doc_ind [145, 324]
# similar_doc_ind [146, 254]
# similar_doc_ind [147, 363]
# similar_doc_ind [149, 556]
# similar_doc_ind [150, 357]
# similar_doc_ind [152, 474]
# similar_doc_ind [153, 724]
# similar_doc_ind [155, 433]
# similar_doc_ind [156, 736]
# similar_doc_ind [157, 738]
# similar_doc_ind [158, 253]
# similar_doc_ind [160, 411]
# similar_doc_ind [162, 214]
# similar_doc_ind [163, 459]
# similar_doc_ind [164, 808]
# similar_doc_ind [167, 860]
# similar_doc_ind [168, 782]
# similar_doc_ind [169, 612]
# similar_doc_ind [170, 378]
# similar_doc_ind [171, 204]
# similar_doc_ind [172, 391]
# similar_doc_ind [173, 587]
# similar_doc_ind [175, 347]
# similar_doc_ind [177, 599]
# similar_doc_ind [178, 625]
# similar_doc_ind [180, 396]
# similar_doc_ind [181, 416]
# similar_doc_ind [182, 264]
# similar_doc_ind [183, 282]
# similar_doc_ind [185, 749]
# similar_doc_ind [186, 565]
# similar_doc_ind [187, 554]
# similar_doc_ind [188, 722]
# similar_doc_ind [189, 232]
# similar_doc_ind [195, 479]
# similar_doc_ind [196, 335]
# similar_doc_ind [197, 829]
# similar_doc_ind [199, 931]
# similar_doc_ind [200, 766]
# similar_doc_ind [201, 331]
# similar_doc_ind [202, 313]
# similar_doc_ind [205, 249]
# similar_doc_ind [206, 352]
# similar_doc_ind [207, 385]
# similar_doc_ind [208, 944]
# similar_doc_ind [209, 908]
# similar_doc_ind [210, 256]
# similar_doc_ind [211, 690]
# similar_doc_ind [212, 509]
# similar_doc_ind [215, 402]
# similar_doc_ind [216, 714]
# similar_doc_ind [217, 731]
# similar_doc_ind [218, 368]
# similar_doc_ind [220, 567]
# similar_doc_ind [221, 582]
# similar_doc_ind [222, 825]
# similar_doc_ind [223, 684]
# similar_doc_ind [225, 626]
# similar_doc_ind [226, 629]
# similar_doc_ind [228, 461]
# similar_doc_ind [229, 230]
# similar_doc_ind [233, 333]
# similar_doc_ind [234, 408]
# similar_doc_ind [235, 557]
# similar_doc_ind [237, 779]
# similar_doc_ind [238, 240]
# similar_doc_ind [239, 345]
# similar_doc_ind [242, 364]
# similar_doc_ind [245, 817]
# similar_doc_ind [247, 784]
# similar_doc_ind [251, 257]
# similar_doc_ind [258, 462]
# similar_doc_ind [259, 639]
# similar_doc_ind [260, 812]
# similar_doc_ind [261, 710]
# similar_doc_ind [262, 423]
# similar_doc_ind [263, 398]
# similar_doc_ind [267, 622]
# similar_doc_ind [270, 271]
# similar_doc_ind [272, 454]
# similar_doc_ind [273, 597]
# similar_doc_ind [275, 643]
# similar_doc_ind [276, 297]
# similar_doc_ind [277, 796]
# similar_doc_ind [278, 672]
# similar_doc_ind [279, 708]
# similar_doc_ind [280, 886]
# similar_doc_ind [281, 883]
# similar_doc_ind [283, 448]
# similar_doc_ind [285, 417]
# similar_doc_ind [286, 847]
# similar_doc_ind [289, 375]
# similar_doc_ind [290, 529]
# similar_doc_ind [291, 438]
# similar_doc_ind [292, 532]
# similar_doc_ind [293, 820]
# similar_doc_ind [294, 414]
# similar_doc_ind [295, 518]
# similar_doc_ind [296, 741]
# similar_doc_ind [299, 938]
# similar_doc_ind [300, 910]
# similar_doc_ind [304, 549]
# similar_doc_ind [305, 837]
# similar_doc_ind [306, 319]
# similar_doc_ind [307, 585]
# similar_doc_ind [308, 575]
# similar_doc_ind [309, 739]
# similar_doc_ind [310, 312]
# similar_doc_ind [315, 665]
# similar_doc_ind [316, 399]
# similar_doc_ind [317, 356]
# similar_doc_ind [320, 401]
# similar_doc_ind [321, 569]
# similar_doc_ind [322, 406]
# similar_doc_ind [323, 516]
# similar_doc_ind [325, 928]
# similar_doc_ind [326, 418]
# similar_doc_ind [327, 502]
# similar_doc_ind [328, 432]
# similar_doc_ind [330, 442]
# similar_doc_ind [332, 365]
# similar_doc_ind [334, 888]
# similar_doc_ind [336, 644]
# similar_doc_ind [337, 350]
# similar_doc_ind [338, 773]
# similar_doc_ind [339, 445]
# similar_doc_ind [340, 559]
# similar_doc_ind [341, 717]
# similar_doc_ind [342, 852]
# similar_doc_ind [343, 491]
# similar_doc_ind [344, 914]
# similar_doc_ind [346, 774]
# similar_doc_ind [348, 607]
# similar_doc_ind [349, 767]
# similar_doc_ind [351, 553]
# similar_doc_ind [353, 592]
# similar_doc_ind [358, 470]
# similar_doc_ind [359, 360]
# similar_doc_ind [361, 397]
# similar_doc_ind [362, 882]
# similar_doc_ind [366, 862]
# similar_doc_ind [367, 431]
# similar_doc_ind [371, 896]
# similar_doc_ind [373, 868]
# similar_doc_ind [374, 602]
# similar_doc_ind [376, 421]
# similar_doc_ind [377, 463]
# similar_doc_ind [379, 507]
# similar_doc_ind [380, 594]
# similar_doc_ind [381, 382]
# similar_doc_ind [383, 611]
# similar_doc_ind [386, 870]
# similar_doc_ind [387, 664]
# similar_doc_ind [389, 740]
# similar_doc_ind [390, 437]
# similar_doc_ind [392, 764]
# similar_doc_ind [394, 742]
# similar_doc_ind [404, 415]
# similar_doc_ind [405, 792]
# similar_doc_ind [407, 921]
# similar_doc_ind [409, 589]
# similar_doc_ind [410, 451]
# similar_doc_ind [412, 819]
# similar_doc_ind [419, 806]
# similar_doc_ind [420, 471]
# similar_doc_ind [422, 879]
# similar_doc_ind [426, 447]
# similar_doc_ind [427, 636]
# similar_doc_ind [428, 702]
# similar_doc_ind [430, 771]
# similar_doc_ind [434, 508]
# similar_doc_ind [435, 603]
# similar_doc_ind [440, 850]
# similar_doc_ind [441, 577]
# similar_doc_ind [443, 854]
# similar_doc_ind [444, 568]
# similar_doc_ind [446, 911]
# similar_doc_ind [449, 620]
# similar_doc_ind [450, 652]
# similar_doc_ind [452, 840]
# similar_doc_ind [453, 632]
# similar_doc_ind [455, 827]
# similar_doc_ind [456, 807]
# similar_doc_ind [457, 654]
# similar_doc_ind [458, 623]
# similar_doc_ind [460, 887]
# similar_doc_ind [464, 810]
# similar_doc_ind [465, 468]
# similar_doc_ind [466, 606]
# similar_doc_ind [467, 555]
# similar_doc_ind [469, 681]
# similar_doc_ind [472, 475]
# similar_doc_ind [473, 930]
# similar_doc_ind [476, 581]
# similar_doc_ind [477, 891]
# similar_doc_ind [478, 692]
# similar_doc_ind [480, 793]
# similar_doc_ind [481, 583]
# similar_doc_ind [482, 875]
# similar_doc_ind [483, 688]
# similar_doc_ind [484, 725]
# similar_doc_ind [485, 650]
# similar_doc_ind [486, 830]
# similar_doc_ind [487, 618]
# similar_doc_ind [489, 885]
# similar_doc_ind [490, 791]
# similar_doc_ind [492, 919]
# similar_doc_ind [493, 760]
# similar_doc_ind [494, 909]
# similar_doc_ind [495, 523]
# similar_doc_ind [496, 533]
# similar_doc_ind [497, 866]
# similar_doc_ind [499, 932]
# similar_doc_ind [500, 548]
# similar_doc_ind [503, 876]
# similar_doc_ind [504, 922]
# similar_doc_ind [505, 659]
# similar_doc_ind [506, 777]
# similar_doc_ind [510, 759]
# similar_doc_ind [511, 787]
# similar_doc_ind [512, 788]
# similar_doc_ind [513, 772]
# similar_doc_ind [514, 628]
# similar_doc_ind [517, 635]
# similar_doc_ind [519, 853]
# similar_doc_ind [520, 726]
# similar_doc_ind [521, 865]
# similar_doc_ind [522, 715]
# similar_doc_ind [524, 676]
# similar_doc_ind [526, 933]
# similar_doc_ind [527, 546]
# similar_doc_ind [528, 531]
# similar_doc_ind [535, 800]
# similar_doc_ind [536, 660]
# similar_doc_ind [537, 927]
# similar_doc_ind [538, 871]
# similar_doc_ind [541, 901]
# similar_doc_ind [542, 678]
# similar_doc_ind [543, 691]
# similar_doc_ind [544, 929]
# similar_doc_ind [545, 758]
# similar_doc_ind [547, 671]
# similar_doc_ind [550, 895]
# similar_doc_ind [551, 655]
# similar_doc_ind [552, 574]
# similar_doc_ind [560, 656]
# similar_doc_ind [561, 939]
# similar_doc_ind [562, 878]
# similar_doc_ind [563, 893]
# similar_doc_ind [564, 737]
# similar_doc_ind [566, 789]
# similar_doc_ind [570, 762]
# similar_doc_ind [572, 591]
# similar_doc_ind [573, 844]
# similar_doc_ind [578, 600]
# similar_doc_ind [580, 713]
# similar_doc_ind [584, 925]
# similar_doc_ind [586, 838]
# similar_doc_ind [588, 761]
# similar_doc_ind [593, 744]
# similar_doc_ind [595, 614]
# similar_doc_ind [596, 699]
# similar_doc_ind [598, 605]
# similar_doc_ind [601, 889]
# similar_doc_ind [608, 897]
# similar_doc_ind [609, 816]
# similar_doc_ind [610, 785]
# similar_doc_ind [613, 696]
# similar_doc_ind [616, 768]
# similar_doc_ind [617, 701]
# similar_doc_ind [619, 630]
# similar_doc_ind [621, 890]
# similar_doc_ind [627, 662]
# similar_doc_ind [631, 861]
# similar_doc_ind [634, 795]
# similar_doc_ind [638, 750]
# similar_doc_ind [640, 695]
# similar_doc_ind [641, 856]
# similar_doc_ind [642, 645]
# similar_doc_ind [647, 752]
# similar_doc_ind [649, 818]
# similar_doc_ind [651, 814]
# similar_doc_ind [657, 941]
# similar_doc_ind [658, 894]
# similar_doc_ind [661, 836]
# similar_doc_ind [663, 811]
# similar_doc_ind [666, 668]
# similar_doc_ind [669, 720]
# similar_doc_ind [670, 797]
# similar_doc_ind [673, 880]
# similar_doc_ind [674, 915]
# similar_doc_ind [675, 743]
# similar_doc_ind [677, 680]
# similar_doc_ind [679, 756]
# similar_doc_ind [682, 683]
# similar_doc_ind [686, 783]
# similar_doc_ind [687, 828]
# similar_doc_ind [689, 874]
# similar_doc_ind [693, 705]
# similar_doc_ind [694, 823]
# similar_doc_ind [697, 698]
# similar_doc_ind [704, 835]
# similar_doc_ind [706, 803]
# similar_doc_ind [707, 858]
# similar_doc_ind [709, 799]
# similar_doc_ind [711, 892]
# similar_doc_ind [712, 877]
# similar_doc_ind [716, 746]
# similar_doc_ind [718, 940]
# similar_doc_ind [719, 826]
# similar_doc_ind [721, 751]
# similar_doc_ind [723, 849]
# similar_doc_ind [727, 780]
# similar_doc_ind [729, 748]
# similar_doc_ind [730, 935]
# similar_doc_ind [732, 733]
# similar_doc_ind [734, 851]
# similar_doc_ind [735, 775]
# similar_doc_ind [745, 832]
# similar_doc_ind [747, 906]
# similar_doc_ind [753, 873]
# similar_doc_ind [757, 863]
# similar_doc_ind [763, 778]
# similar_doc_ind [765, 805]
# similar_doc_ind [769, 869]
# similar_doc_ind [770, 841]
# similar_doc_ind [781, 833]
# similar_doc_ind [786, 813]
# similar_doc_ind [790, 804]
# similar_doc_ind [794, 936]
# similar_doc_ind [798, 918]
# similar_doc_ind [815, 845]
# similar_doc_ind [821, 884]
# similar_doc_ind [822, 913]
# similar_doc_ind [824, 917]
# similar_doc_ind [834, 857]
# similar_doc_ind [842, 903]
# similar_doc_ind [843, 881]
# similar_doc_ind [846, 859]
# similar_doc_ind [848, 923]
# similar_doc_ind [864, 867]
# similar_doc_ind [872, 943]
# similar_doc_ind [899, 905]
# similar_doc_ind [900, 934]
# similar_doc_ind [902, 916]
# similar_doc_ind [904, 926]
# similar_doc_ind [912, 942]
# similar_doc_ind [937, 945]
# Breaking after moving over 946 of all 946 indexes.
# unused_indexes: []
# End: get_anonym_degree: 1
# (1, [[320], [401], [705], [693], [902], [916]])

# %%
curr_k, non_anon_indexes = anonym_utils.get_anonym_degree(force_anon_txt_annoy)
print('Current k:', curr_k, '\tnumber of un-anonym. documents:', len(non_anon_indexes), '\tnumber of all documents:', len(df_2['txt']))
# Out:
# Current k: 1 	number of un-anonym. documents: 6 	number of all documents: 946

# %%
df_2['force_anon_txt'] = force_anon_txt_annoy
# Counting the number of words and *
df_2['num_of_words_after_forcing'] = df_2['force_anon_txt'].apply(lambda x: len(re.findall(r'\w+', x)))
df_2['num_of_deleting_after_forcing'] = df_2['force_anon_txt'].apply(lambda x: len(re.findall(r'\*', x)))

# %%
y = np.array([df_2['num_of_words_after_forcing'].sum(), df_2['num_of_deleting_after_forcing'].sum()])
mylabels = ['words kept', 'words masked']

plt.pie(y, labels = mylabels)
plt.title('Words in dataset')
plt.show()

# %%
y = np.array([df_2['num_protected'].sum(), df_2['num_of_deleting_after_forcing'].sum(), (df_2['num_of_words_after_forcing'] - df_2['num_protected']).sum()])
mylabels = ['protected', 'masked', 'no change']

plt.pie(y, labels = mylabels)
plt.title('Words in dataset')
plt.show()

# %%
i = 1
print(df_2['txt'][i])
print(df_2['anon_txt_history'][i])
print(df_2['force_anon_txt'][i])
# Out:
# just awful: this was possibly the worst book i have ever read. i am amazed by the number of fans for this kind of rubbish.
# (just) [worse] (this) (was) possibly (the) {bad} (book) (i) (have) (ever) (read.) (i) (am) {amaze} (by) (the) (number) (of) {fan} (for) (this) (kind) (of) rubbish.
# just * : this was * the bad book i have ever read . i am * by the * of * for this * of * .

# %% [markdown]
# ## 5) Utilization tests

# %%
df_21 = utilization_utils.get_vader_sentiment_for_df(df_2, ['txt', 'anon_txt', 'force_anon_txt'])
df_21
# Out:
#      Unnamed: 0                                                txt  sentiment
# 0            99  caution!: these tracks are not the "original" ...          0  \
# 1           461  just awful: this was possibly the worst book i...          0
# 2           493  no lessons learned: this is one of the most di...          0
# 3           578  squeem: i ordered according to the size chart ...          0
# 4           595  pass: the sizes run really small, it flips up ...          0
# ..          ...                                                ...        ...
# 941       20710  excellent: prompt delivery. correct parts. you...          1
# 942       20711  purchased minn kota mkp 3 prop from amazon.com...          1
# 943       20738  plantronics bluetooth 665 charger: this charge...          1
# 944       20784  video purchase: like the movie so i bought it....          1
# 945       20790  freakin' funny!!!!!!!!!!!!!!!!!!!!!!!!: if you...          1
#
#      num_of_words                                           anon_txt
# 0              22  caution ! : these track are not the " original...  \
# 1              25  just worse : this was possibly the bad book i ...
# 2              23  no lesson learn : this is one of the most disa...
# 3              21  squeem : i order accord to the size chart for ...
# 4              25  pass : the size run really small , it shoe up ...
# ..            ...                                                ...
# 941            24  excellent : in-depth delivery . correct part ....
# 942            25  purchase minn kota mkp 3 prop from amazon.com ...
# 943            28  plantronic bluetooth 665 charger : this charge...
# 944            18  video purchase : like the song so i buy it . r...
# 945            20  freakin ' funny ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ...
#
#                                       anon_txt_history  num_replaced
# 0    caution!: (these) {track} (are) (not) (the) ("...             0  \
# 1    (just) [worse] (this) (was) possibly (the) {ba...             1
# 2    (no) {lesson} {learn} (this) (is) (one) (of) (...             1
# 3    squeem: (i) {order} {accord} (to) (the) (size)...             0
# 4    (pass:) (the) {size} (run) really (small,) (it...             0
# ..                                                 ...           ...
# 941  excellent: [in-depth] delivery. (correct) {par...             0
# 942  {purchase} minn kota mkp 3 prop (from) amazon....             0
# 943  {plantronic} bluetooth 665 charger: (this) cha...             0
# 944  video purchase: (like) (the) [song] (so) (i) (...             2
# 945  {freakin} funny!!!!!!!!!!!!!!!!!!!!!!!!: (if) ...             0
#
#      num_lemmatized  num_protected  num_no_change
# 0                 6             12              4  \
# 1                 3             18              3
# 2                 3             14              5
# 3                 4             13              4
# 4                 4             15              6
# ..              ...            ...            ...
# 941               4             12              8
# 942               3             13              9
# 943               2             16             10
# 944               1             10              5
# 945               4             11              5
#
#                                         force_anon_txt
# 0    * ! : these * are not the " original " version...  \
# 1    just * : this was * the bad book i have ever r...
# 2    no lesson * : this is one of * most * * i have...
# 3    * : i order * to the size * for my * and it wa...
# 4    * : the size * * * , it shoe up * * , they * i...
# ..                                                 ...
# 941  excellent : in - * * . * * . you can not do * ...
# 942  * * * * 3 * from *.* . : the * was * what i * ...
# 943  * * * * : this * is great for time when you do...
# 944  * * : like the song so i * it . * the hd in * ...
# 945  * ' * ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ...
#
#      num_of_words_after_forcing  num_of_deleting_after_forcing
# 0                            17                              6  \
# 1                            18                              7
# 2                            13                             11
# 3                            16                              6
# 4                            16                             10
# ..                          ...                            ...
# 941                          16                             10
# 942                          14                             12
# 943                          19                             10
# 944                          11                              7
# 945                          10                             11
#
#      txt_vader_sentiment_pred  anon_txt_vader_sentiment_pred
# 0                      0.0000                        -0.1957  \
# 1                     -0.5574                        -0.2023
# 2                     -0.5563                        -0.5563
# 3                      0.0000                         0.0000
# 4                      0.0000                         0.0000
# ..                        ...                            ...
# 941                    0.8622                         0.8313
# 942                    0.0000                         0.0000
# 943                    0.7841                         0.7841
# 944                    0.8655                         0.8655
# 945                   -0.7946                        -0.6876
#
#      force_anon_txt_vader_sentiment_pred
# 0                                -0.1957
# 1                                -0.5423
# 2                                -0.2960
# 3                                 0.0000
# 4                                 0.0000
# ..                                   ...
# 941                               0.7712
# 942                               0.0000
# 943                               0.7650
# 944                               0.3612
# 945                               0.0000
#
# [946 rows x 16 columns]

# %%
import matplotlib.pyplot as plt

plt.scatter(df_21['txt_vader_sentiment_pred'], df_21['anon_txt_vader_sentiment_pred'])
plt.xlabel('Before annoymization')
plt.ylabel('After annonymization')
plt.title('Sentiment score before and after annonymization');

# %%
plt.scatter(df_21['txt_vader_sentiment_pred'], df_21['force_anon_txt_vader_sentiment_pred'])
plt.xlabel('Before annoymization')
plt.ylabel('After annonymization')
plt.title('Sentiment score before and after annonymization');

# %% [markdown]
# ### Using Naive Bayes

# %%
utilization_utils.sentiment_test(df_2, 'txt')
# Out:
# 0.8858246688505911

# %%
utilization_utils.sentiment_test(df_2, 'anon_txt')
# Out:
# 0.8762996724113374

# %% [markdown]
# The fully anonymized text gets he highest accuracy score!

# %%
utilization_utils.sentiment_test(df_2, 'force_anon_txt')
# Out:
# 0.7863997293832787

# %% [markdown]
# ### Using XGBoost

# %%
utilization_utils.sentiment_test(df_2, 'txt')
# Out:
# 0.8858246688505911

# %%
utilization_utils.sentiment_test(df_2, 'anon_txt')
# Out:
# 0.8762996724113374

# %%
utilization_utils.sentiment_test(df_2, 'force_anon_txt')
# Out:
# 0.7863997293832787

# %% [markdown]
# ## Saving output

# %%
filename = 'outputs/' + output_name
df_2.to_csv(filename, index=False)

# %% [markdown]
# ### Temp and tries

# %%
print(nlp_utils.stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
len(nlp_utils.stopwords.words('english'))
# Out:
# 179

# %%
len(nlp_utils.stopword_list)
# Out:
# 179

# %%
nlp_utils.add_word_list_to_stop_words('data/1000_most_common_words.txt')
len(nlp_utils.stopword_list)
# Out:
# 1075
